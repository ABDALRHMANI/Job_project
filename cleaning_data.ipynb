# %%
import pandas as pd
import re

# %% [markdown]
# ## prepare both data frames to combine thim

# %%
wuz_df=pd.read_csv('Wuzzaf_jobs.csv')

wuz_df.head()

gulf_df=pd.read_csv("naukrigulf_jobs.csv")
gulf_df.head()
# Out:
#    Unnamed: 0                                          Education  \
# 0         NaN                                     Any Graduation
# 1         NaN                     CA Inter(Chartered Accountant)
# 2         NaN                     CA Inter(Chartered Accountant)
# 3         NaN                     CA Inter(Chartered Accountant)
# 4         NaN  Bachelor of Technology/Engineering(Computers, ...
#
#                          Job Location Benefits Gender  \
# 0  Dubai - United Arab Emirates (UAE)      NaN    Any
# 1                 Abha - Saudi Arabia      NaN    Any
# 2                 Abha - Saudi Arabia      NaN    Any
# 3                 Abha - Saudi Arabia      NaN    Any
# 4  Ajman - United Arab Emirates (UAE)      NaN    Any
#
#                             job_title          company_name  \
# 0                             IT Head  Confidential Company
# 1                  Software Engineer1       fnhvefjh vejh v
# 2                  Software Engineer1            NG company
# 3                   Software Engineer       subuser profile
# 4  Software Engineer/ Java Developers  Thumbay Technologies
#
#                          Monthly Salary  \
# 0                                   NaN
# 1      AED 1,000 - 2,000  ($271 - $541)
# 2      AED 1,000 - 2,000  ($271 - $541)
# 3      AED 1,000 - 2,000  ($271 - $541)
# 4  AED 5,000 - 6,000  ($1,351 - $1,621)
#
#                                 Nationality  \
# 0                           Any Nationality
# 1  Any Arab National, Any European National
# 2  Any Arab National, Any European National
# 3                         Any Arab National
# 4        Indian, Pakistani, Any Nationality
#
#                                      job_description     Experience  \
# 0  Job DescriptionRoles & ResponsibilitiesAs the ...  10 - 16 Years
# 1  Job DescriptionRoles & ResponsibilitiesCollabo...    2 - 4 Years
# 2  Job DescriptionRoles & ResponsibilitiesCollabo...    2 - 4 Years
# 3  Job DescriptionRoles & ResponsibilitiesCollabo...    2 - 4 Years
# 4  Job DescriptionRoles & ResponsibilitiesJob Des...    3 - 4 Years
#
#        Vacancy
# 0    1 Vacancy
# 1    1 Vacancy
# 2    1 Vacancy
# 3    1 Vacancy
# 4  2 Vacancies

# %% [markdown]
# ### drop duplicates

# %%
print(f"len before the duplicates {len(wuz_df)}")
wuz_df.drop_duplicates(inplace=True)
print(f"len after the duplicates {len(wuz_df)}")
# Out:
# len before the duplicates 1028
# len after the duplicates 1025

# %%
print(f"len before the duplicates {len(gulf_df)}")
gulf_df.drop_duplicates(inplace=True)
print(f"len after the duplicates {len(gulf_df)}")
# Out:
# len before the duplicates 2970
# len after the duplicates 2915

# %% [markdown]
# ### delete unuseful columns

# %%
wuz_df['company_name']=wuz_df['company_name'].fillna('unkown')

# %%
wuz_df = wuz_df.dropna(subset=['job_title'])

# %%
# so it doesnt give us enough information its better to delete it 
print(len(wuz_df[wuz_df['salary'].str.contains('Confidential') == True]))
wuz_df.drop(columns=['salary'],inplace=True)
# Out:
# 845

# %%
# so this 3 columns have not enough information so we will delete thim
print(gulf_df['Benefits'].value_counts())

print(gulf_df['Gender'].value_counts())
	
print(gulf_df['Vacancy'].value_counts())

# we delete monthly sales because its 47 non_null value only so its over 90% null
gulf_df.drop(columns=['Gender','Unnamed: 0','Benefits','Monthly Salary','Nationality','Vacancy'],inplace=True)
# Out:
# Benefits
# Annual Air Ticket, Annual Leaves As Per Labour Law, Medical Insurance, Visa, Perks & Benefits As Per Labour Law                 1
# Visa, Food, Paid Leaves, Medical Insurance, Life Insurance                                                                      1
# Commission, Annual Air Ticket                                                                                                   1
# Annual Air Ticket, Annual Leaves As Per Labour Law, Life Insurance, Medical Insurance                                           1
# Visa, Medical Insurance                                                                                                         1
# Annual Air Ticket, Annual Leaves As Per Labour Law, Car, Medical Insurance, Visa                                                1
# Annual Leaves As Per Labour Law, Annual Air Ticket, Visa, Medical Insurance                                                     1
# Annual Air Ticket, Medical Insurance, Paid Leaves, Visa                                                                         1
# Visa, Medical Insurance, Annual Leaves As Per Labour Law                                                                        1
# Perks & Benefits As Per Labour Law,  Paid Leaves,  Visa, Annual Air Ticket, Medical Insurance                                   1
# Annual Air Ticket, Annual Leaves As Per Labour Law, Medical Insurance, Paid Leaves, Visa, Perks & Benefits As Per Labour Law    1
# Accomodation, Annual Air Ticket, Annual Leaves As Per Labour Law, Life Insurance, Medical Insurance, Visa, Paid Leaves          1
# Visa,  Medical Insurance,  Annual Leaves As Per Labour Law, Annual Air Ticket                                                   1
# Visa, Paid Leaves, Medical Insurance, Annual Air Ticket                                                                         1
# Accomodation, Annual Air Ticket, Food, Medical Insurance, Transportation                                                        1
# Name: count, dtype: int64
# Gender
# Not Mentioned    2766
# Any               127
# Male               15
# Female              5
# Name: count, dtype: int64
# Vacancy
# 1 Vacancy       2870
# 2 Vacancies       19
# 3 Vacancies       12
# 10 Vacancies       4
# 5 Vacancies        3
# 30 Vacancies       1
# 50 Vacancies       1
# 6 Vacancies        1
# 20 Vacancies       1
# 4 Vacancies        1
# Name: count, dtype: int64

# %% [markdown]
# ### rename the columns to ensure consistency between the 2 dataframes

# %%
wuz_df.rename(columns={'the_place':'Job Location'},inplace=True)


wuz_df.rename(columns={'experience':'Experience'},inplace=True)


wuz_df.rename(columns={'education_level':'Education'},inplace=True)

# %% [markdown]
# ### refactor columns to make analysing easier

# %%
print(wuz_df['Experience'].unique())
print("\nnotice the differance\n")
print(gulf_df['Experience'].unique())

wuz_df['Experience']=wuz_df['Experience'].apply(lambda x:str(x).replace('to','-').lower())

gulf_df['Experience']=gulf_df['Experience'].apply(lambda x:str(x).lower())
# Out:
# ['3 to 5 years' '1 to 3 years' '5 to 6 years' '2 to 4 years'
#  '5 to 10 years' '4 to 10 years' '2 years' '10 to 15 years' '4 to 7 years'
#  '2 to 5 years' '7 to 12 years' '2 to 3 years' '0 to 3 years'
#  '0 to 2 years' '8 to 10 years' '7 to 15 years' '4 to 5 years'
#  '3 to 10 years' 'More than 5 years' 'More than 2 years'
#  'More than 1 year' '5 to 7 years' '4 to 6 years' '1 to 2 years'
#  '10 to 16 years' '5 to 8 years' 'Not Specified' '0 to 7 years'
#  '14 to 20 years' '3 to 20 years' '3 to 6 years' '2 to 6 years'
#  'More than 3 years' '2 to 7 years' '10 to 12 years' '5 to 9 years'
#  '3 to 4 years' '5 to 15 years' '0 to 15 years' '1 to 5 years'
#  '2 to 8 years' '5 to 12 years' 'More than 4 years' '0 to 5 years'
#  '2 to 20 years' '4 to 8 years' '3 to 7 years' '1 to 20 years'
#  '2 to 10 years' '0 to 1 year' '6 to 8 years' 'More than 9 years'
#  '7 to 10 years' '0 to 10 years' '7 to 20 years' '3 to 12 years'
#  '3 to 8 years' '7 to 9 years' '8 to 15 years' 'More than 10 years'
#  'More than 8 years' '3 to 9 years' '3 to 17 years' '6 to 10 years'
#  '10 years' 'More than 7 years' '1 to 4 years' '5 years' nan
#  '6 to 20 years' '5 to 20 years' '1 to 7 years' '2 to 12 years'
#  '1 to 10 years' '3 years' '20 years' '15 to 20 years' '2 to 15 years'
#  '1 to 8 years' '4 to 20 years' '8 to 12 years']
#
# notice the differance
#
# ['10 - 16 Years' '2 - 4 Years' '3 - 4 Years' '5 - 10 Years' '8 - 13 Years'
#  '15 - 20 Years' '3 - 5 Years' '1 - 2 Years' '5 - 7 Years' '2 - 5 Years'
#  '7 - 10 Years' '4 - 7 Years' '3 - 9 Years' '3 - 6 Years' '3 - 7 Years'
#  '7 - 8 Years' '2 - 7 Years' '2 - 3 Years' '6 - 10 Years' '8 - 12 Years'
#  nan '1 - 4 Years' '5 - 8 Years' '4 - 6 Years' '3 - 8 Years' '1 - 3 Years'
#  '1 - 6 Years' '0 - 2 Years' '1 - 5 Years' '6 - 12 Years' '2 - 6 Years'
#  '6 - 8 Years' '3 - 10 Years' '10 - 15 Years' '10 - 11 Years'
#  '9 - 10 Years' '9 - 15 Years' '7 - 9 Years' '0 - 1 Year' '2 - 8 Years'
#  '6 - 9 Years' '12 - 14 Years' '8 - 11 Years' '8 - 10 Years'
#  '4 - 10 Years' '7 - 14 Years' '0 - 3 Years' '0 - 5 Years' '5 - 9 Years'
#  '1 - 8 Years' '10 - 12 Years' '5 - 6 Years' '2 - 12 Years' '4 - 8 Years'
#  '4 - 9 Years' '4 - 5 Years' '6 - 7 Years' '20 - 25 Years' '10 - 20 Years'
#  '8 - 15 Years' '15 - 17 Years' '7 - 12 Years' '12 - 13 Years'
#  '10 - 13 Years' '0 - 7 Years' '10 - 17 Years' '9 - 12 Years'
#  '0 - 4 Years' '5 - 12 Years' '25 - 26 Years' '9 - 16 Years'
#  '8 - 14 Years' '6 - 11 Years' '7 - 11 Years' '0 - 6 Years'
#  '15 - 18 Years' '2 - 10 Years' '9 - 14 Years' '15 - 19 Years'
#  '15 - 27 Years' '12 - 15 Years' '25 - 29 Years' '10 - 14 Years'
#  '7 - 13 Years' '5 Years' '12 - 16 Years' '5 - 15 Years' '25 - 27 Years'
#  '9 - 11 Years' '5 - 20 Years' '8 - 9 Years' '20 - 22 Years' '7+ Years'
#  '14 - 17 Years' '20 - 23 Years' '9 - 13 Years' '11 - 25 Years'
#  '12 - 20 Years' '14 - 19 Years' '10 - 18 Years' '1 - 7 Years'
#  '3 - 20 Years' '2 - 9 Years' '1 - 10 Years' '18 - 20 Years'
#  '7 - 16 Years' '3 - 18 Years' '3 - 12 Years']

# %%
print(wuz_df['Job Location'].unique())
print("\nnotice the differance\n")
print(gulf_df['Job Location'].unique())

wuz_df['Job Location']=wuz_df['Job Location'].apply(lambda x:str(x).replace(',',' -'))
# Out:
# ['Smart Village, Giza' 'Mohandessin, Giza' 'New Cairo, Cairo'
#  'Glim, Alexandria' 'Manial, Cairo' 'Giza, Egypt' 'Alexandria, Egypt'
#  'Bolkly, Alexandria' 'Cairo, Egypt' '6th of October, Giza'
#  'Abbassia, Cairo' 'Maadi, Cairo' 'Nasr City, Cairo' 'Obour City, Cairo'
#  'Abu Rawash, Giza' 'Bank' 'Heliopolis, Cairo' 'Riyadh, Saudi Arabia'
#  '10th of Ramadan City, Cairo' 'Qantara Gharb, Ismailia'
#  'New Capital, Cairo' 'Nozha, Cairo' 'eg.com' 'Atlanta, United States'
#  'Sharjah, United Arab Emirates' 'Cairo, Egypt Not Verified'
#  'McAllen, United States' 'Doha, Qatar' 'Dokki, Giza' 'Garden City, Cairo'
#  'Sheraton, Cairo' 'Katameya, Cairo' 'Alsadat City, Monufya'
#  'Downtown, Cairo' 'Smouha, Alexandria' 'khanka, Qalubia' 'Intrasoft'
#  'Cashi' 'Mansoura, Dakahlia' 'Egypt Gold' 'Hadayek October, Giza'
#  'Obour City, Cairo Not Verified' 'Shorouk City, Cairo' 'IT'
#  'Abdeen, Cairo' 'Sheikh Zayed, Giza' 'Ameria, Alexandria'
#  'Shubra Alkhaymah, Qalubia' 'San Stefano, Alexandria'
#  'Mahalla Kubra, Gharbia' 'Kuwait City, Kuwait' 'Rome, Italy'
#  'London, United Kingdom' 'Mississauga, Canada' 'Cairo, Egypt New company'
#  'Boulaq, Cairo' 'Attarin, Alexandria' 'paym...' 'Bath, United Kingdom'
#  'Center of ...' 'Port Said, Egypt' 'finance' 'Hail, Saudi Arabia'
#  '10th of Ramadan City, Sharqia' 'Technologies' 'New Nozha, Cairo' 'Egypt'
#  'Santa Barbara, United States' 'Dubai, United Arab Emirates'
#  'Mokattam, Cairo' 'Muscat, Oman' 'Istanbul, Turkey' 'Basatin, Cairo'
#  'Giza, Giza' 'Rabat, Morocco' 'Zamalek, Cairo' 'Click Adv' 'Mubarak Al'
#  'Munich GmbH' 'Salam City, Cairo' 'Helwan, Cairo' 'Ahram Group' 'P...'
#  'Assiut, Egypt' 'Jerusalem, Palestine' 'Birmingham, United Kingdom'
#  'Paris, France' 'Victoria, Alexandria' 'Jeddah, Saudi Arabia'
#  'Haram, Giza' 'East Los Angeles, United States' 'Madinaty, Cairo'
#  'Faisal, Giza' 'GEO Solutions' 'رؤيه' 'Port Fuad, Port Said'
#  'Darrasa, Cairo' 'Zamalek, Cairo Not Verified' 'Charlotte, United States'
#  'Manchester, United Kingdom Not Verified' 'Beni Suef, Beni Suef'
#  'Fleming, Alexandria' 'Mit Ghamr, Dakahlia'
#  'Abu Dhabi, United Arab Emirates' 'Ajman, United Arab Emirates'
#  'Dr Khaled ...' 'Badr City, Cairo' 'Wadi Alnatrun, Beheira' 'Th...'
#  'Bourj Alarab, Alexandria' 'Banha, Qalubia'
#  'New Cairo, Cairo Not Verified' 'Alamein, Matruh' 'Vancouver, Canada'
#  'Ataqah, Suez' 'Mham' 'Amman, Jordan' 'Dallas, United States'
#  'Malaz for Information...' 'HSA' 'Mahta Alraml, Alexandria'
#  'Ain Shams, Cairo' 'Mec Egypt for Elev...' 'Hadayek Alahram, Giza'
#  'Consultancy' 'Dakahlia, Egypt']
#
# notice the differance
#
# ['Dubai - United Arab Emirates (UAE)' 'Abha - Saudi Arabia'
#  'Ajman - United Arab Emirates (UAE)' 'Dubai - United Arab Emirates'
#  'Cairo - Egypt' 'Riyadh - Saudi Arabia'
#  'Abu Dhabi - United Arab Emirates' 'Egypt - Egypt'
#  'Saudi Arabia - Saudi Arabia'
#  'United Arab Emirates - United Arab Emirates' 'Giza - Egypt' nan
#  'BahrainSaudi Arabia - Bahrain' 'Jeddah - Saudi Arabia'
#  'Alexandria - Egypt' 'Sharqia - Egypt' 'Eastern Province - Saudi Arabia'
#  'Sharjah - United Arab Emirates' 'Sharjah - United Arab Emirates (UAE)'
#  'Abu Dhabi - United Arab Emirates (UAE)'
#  'Dubai, Abu Dhabi - United Arab Emirates (UAE)'
#  'Dammam/Khobar/Eastern Province - Saudi Arabia'
#  'Al Khobar - Saudi Arabia' 'Makkah Al Mukarramah - Saudi Arabia'
#  'Tabouk - Saudi Arabia' 'Ajman - United Arab Emirates' 'Doha - Qatar'
#  'Tabuk City, KSA - Saudi Arabia' 'Al Ula, Saudi Arabia - Saudi Arabia'
#  'SA - Saudi Arabia' 'Ras Al Khaimah - United Arab Emirates (UAE)'
#  'Remote (Company based out of Other - Saudi Arabia)'
#  'Remote (Company based out of Jeddah, Riyadh, Shaybah - Saudi Arabia)'
#  'Other - United Arab Emirates (UAE)' 'EgyptJordanPakistan - Egypt'
#  'Dhahran, Saudi Arabia - Saudi Arabia'
#  'Sheikh Zayd, Arkan Plaza Mall - Egypt'
#  'JordanQatarSaudi ArabiaUnited Arab Emirates - Jordan'
#  'DAHRRAN - Saudi Arabia' 'Al Kuwait - Kuwait'
#  'EgyptJordanLebanon - Egypt' 'Sheikh Zayed, Egypt - Egypt'
#  'Al Madina Al Munawarah - Saudi Arabia' 'Manama - Bahrain'
#  'EgyptLebanon - Egypt' 'Dhahran - Saudi Arabia'
#  'Ras Al Khaimah - United Arab Emirates' 'AE - United Arab Emirates'
#  'Abu Dhabi, Dubai, Sharjah - United Arab Emirates'
#  'BahrainUnited Arab Emirates - Bahrain' 'Khafji - Saudi Arabia'
#  'Red Sea, Egypt - Saudi Arabia'
#  'EgyptTunisiaAlgeriaLibyaMoroccoSudan - Egypt'
#  'Tabouk, Saudi Arabia - Saudi Arabia' 'Jeddah, Riyadh - Saudi Arabia'
#  'Beirut, Tripoli - Lebanon'
#  'JordanQatarTunisiaUnited Arab EmiratesMoroccoPakistan - Jordan'
#  'Fujairah - United Arab Emirates'
#  'Saudi ArabiaUnited Arab Emirates - Saudi Arabia'
#  'Shubra al Khaymah - Egypt' 'Abu Dhabi, Dubai - United Arab Emirates'
#  'OmanSaudi ArabiaUnited Arab Emirates - Oman' 'Jubail - Saudi Arabia'
#  'Monufya - Egypt' 'Fujairah - United Arab Emirates (UAE)'
#  'Remote (Company based out of Abu Dhabi - United Arab Emirates (UAE))'
#  'Qatar, United Arab Emirates - Qatar']

# %% [markdown]
# ## combine the 2 data frames

# %%
all_df=pd.concat([wuz_df,gulf_df])

# %%
# here some columns have alot of nulls but we will deal with thim later 
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3939 entries, 0 to 2969
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         3938 non-null   object
#  1   company_name      3938 non-null   object
#  2   Job Location      3937 non-null   object
#  3   Work_Status       1024 non-null   object
#  4   Work_Mode         1017 non-null   object
#  5   Experience        3939 non-null   object
#  6   career_level      1021 non-null   object
#  7   Education         3934 non-null   object
#  8   skills            1021 non-null   object
#  9   job_description   3938 non-null   object
#  10  job_requirements  1008 non-null   object
# dtypes: object(11)
# memory usage: 369.3+ KB

# %% [markdown]
# ### remove the duplicates that jobs shared between the 2 sites

# %%
print(f"len before the duplicates {len(all_df)}")
all_df.drop_duplicates(subset=['job_title','company_name','Experience'],inplace=True)
print(f"len after the duplicates {len(all_df)}")
# Out:
# len before the duplicates 3939
# len after the duplicates 3833

# %% [markdown]
# #### Let's make the 'Job Title' a basic column that holds essential information about the jobs. This will allow us to delve deeper into any group later if needed

# %%
all_df['job_title_basic']=all_df['job_title']

# %% [markdown]
# ### handle the job title column

# %% [markdown]
# #### remove unrelated jobs

# %%
print('before')
print(len(all_df))

all_df = all_df[~all_df['job_title'].str.contains('call center', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('sales', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('marketing', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('content', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('customer service', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('housekeeping', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('digital', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('customer support', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('client support', na=False, case=False)]


print('after')
print(len(all_df))
# Out:
# before
# 3833
# after
# 3685

# %% [markdown]
# #### try to map jobs to bigger groups for better analysing

# %%
# First set of replacements

general_replacements = [
    ('junior', ''),  
    ('senior', ''),  
    ('-', ''),  
    ('&', ' '),  
    ('/', ''),  
    ('(midlevel)', ''),   
    ('remotely', ''),  
    ('midlevel', ''),  
    (' (excel  power bi)', ''),  
    (' next.js 14 ', ''),  
    ('  it  sheraton ', '')  
]
job_mappings = {
    'intern':['internship','intern'],
    'full stack developer': ['full stack', 'end-to-end developer', 'mern', 'mean', 'fullstack','IDM Development','web developer','web prog','Web Development','web researcher','web site developer','website dev','Technical Specialist (WooCommerce Website)'],
    'oracle related job': ['oracle','apex','ADF Developer'],
    'account manager': ['account manager'],
    'angular developer':['typescript developer','angular'],
    'application support': ['application support', 'apm ge support analyst'],
    'backend developer': ['backend', 'api developer', 'node.js', 'java backend', 'server-side developer','back end','. node js','api '],
    'blockchain developer':['blockchain'],
    'business analyst': ['business analyst', 'businessanalysis', 'business analysis', 'business execution analyst','Methodology Analyst','Market Analyst','Delivery Analyst','Planning Analyst','Ancillary Revenue Analyst','performance Analyst','pm analyst','delay analyst','reporting analyst','program associate','workforce planning  analyst','Laundering Analyst','chargeback analyst','Compliance Analyst','business hacker','stock yard analyst','analyst  portfolio support','analyst pmo','analyst transportation','ms tech solutioning   analyst','rpa','Business Process Analyst'],
    'microsoft 365':['microsoft 365','ms 365','365','365 professional'],
    'cloud engineer': ['cloud engineer', 'cloud architect', 'aws', 'azure', 'google cloud','Google Workspace','cloud value rep','Cloud Virtualization Solutions','cloud solutions','IBM Cloud','kubernetes','cloud ','gcp specialis','gcp '],
    'content writer': ['content writer', 'copywriter', 'content creator','Science Communicator','content'],
    'customer support representative': ['customer support representative', 'client relation'],
    'customer support specialist': ['customer support specialist'],
    'coordinator related jobs':['coordinator'],
    'CRM related jobs':['crm ','customer relationship management','customer relationship'],
    'call center jobs':['call center'],
    'data engineer': ['data engineer', 'data pipeline', 'etl developer', 'data wrangler','data center','data processor','Data Section Head','data modeler','fircosoft resource','mdm ','data warehouse','etl ',' informatics developer','Data Centre Transformation','Data Integration','Big Data Expert','data architect'],
    'data governance': ['data governance','information governance','compliance specialist','Data Privacy Officer'],
    'data scientist': ['data scientist', 'data science', 'machine learning','deeplearning','deep learning','machinelearning','ai engineer', 'artificial intelligence', 'ml engineer', 'machine learning engineer','llm','ai manager','ai prog','AI ','computer vision','aiintegrated'],
    'database administrator': ['database administrator', 'database admin', 'data admin','dba','storage and back up','database  administrator'],
    'data entry': ['data entry'],
    'database developer': ['database developer', 'db developer', 'sql developer', 'plsql', 'mysql', 'postgresql'],
    'digital assurance expert engineer': ['digital assurance expert engineer'],
    'digital marketing engineer': ['digital marketing'],
    'digital marketer': ['digital marketer', 'digital marketing specialist', 'seo', 'ppc', 'content marketing'],
    'director related jobs': ['director'],
    'designer': ['product designer', 'ux designer', 'ui designer', 'ui ux','uiux','Packing Development Technology Transfer','ui developer','ux developer','ui prog','ux prog','Ux Manager','ux researcher','ui researcher','CAD Specialist','designer','AutoCAD Draftsman','ux architect'],
    'devops engineer': ['devops'],
    'devsecops engineer': ['devsecops engineer'],
    'dot net developer':['dot net','.net','. net','dotnet','C#','net core','.net core','winforms desktop','net '],
    'doc_related_jobs':['technical documentation','technical writer'],
    'embedded developer': ['embedded','IoT ','Home Automation Engineer','smart homes engineer'],
    'ecm developer':['ecm '],
    'erb related job' : ['erp','AX Technofunctional'],
    'ecommerce specialist': [
    'ecommerce specialist', 'e-commerce specialist'
], 
    'executive related jobs': ['executive'],
    'fp a analyst': ['fp a analyst','financial planning','fp ','Accountant','fintech','finance','investment analyst','FinOps','Actuarial Analyst','Treasury and Support','Financial Planning'],
    'front end developer':['front end','frontend'],
    'graphic related jobs':['graphic'],
    'geospatial jobs': [
        'geospatial', 'geo dev', 'gis dev','geo prog','geo prog', 'geospatial analyst', 
        'geospatial specialist', 'geospatial technician', 
        'geospatial engineer', 'geographic information systems', 'geo analyst','gis ','Mapbox Developer'
    ],
    'game_development_jobs': [
    'game developer', 
    'game designer', 
    'game programmer', 
    'game engineer', 
    'game artist', 
    'game writer', 
    'game producer', 
    'game tester', 
    'game operations', 
    'game data analyst', 
    'technical artist', 
    'Unity Developer'
], 
    'hcm related jobs': ['hcm'],
    'hr specialist': ['human resources', 'recruiter', 'hr manager', 'talent acquisition','technical recruitment'],
    'hris related jobs':['hris'],
    'ict teacher (middle school)': ['ict teacher', 'middle school teacher'],
    'instructor':['instructor','teacher'],
    'information system engineer': ['information systems','information system'],
    'information security engineer': ['information security','infosec','info security'],
    'infrastructure engineer': ['infrastructure engineer','storage administrator','back up','backup','infrastructure analyst','IT System Specialist','IT Onsite Support Officer','Infrastructure Partner','infrastructure architect'],
    'network security engineer': ['network security','Network   Security','Networking   Security'],
    'cyber security engineer': ['cyber security engineer', 'cybersecurity', 'network security','cyber threat','data privacy','data protection', 'information protection section head','Threat Hunting','cyber','soc analyst','threat intelligence analyst','soc   logrythm','devsecops','dfir analyst','IT Security','Firewall','security architect','security analyst','security solutions','Security '],
    'it back office': [
        'it back office', 'it admin','it  admin',
          'itback'  # Removed duplicate 'it back office'
    ],
    'it generalist': [
        'it generalist'
    ],
    'it help desk': [
        'help desk', 'helpdesk','IT Asset','Desk Analyst'  # No changes needed here
    ],
    'it infrastructure': [
        'it infrastructure','Hardware Administrator'
    ],
    'it service related jobs': [
        'it service'
    ],
    'it support': [
        'it support', 'it tech support', 'it operations support', 'IT Supervisor',
        'storage and backup', 'OpenStack Deployment L4 Support Engineer',
        'associate information systems officer', 'L1 support', 'Deskside Support','Service Desk Specialist'
        ,'it technical support','IT Onsite Support Officer'
    ],
    'it specialist': [
        'it specialist'
    ],
    'Information Technology':['it ','Information Technology',],
    'java developer': ['java', 'spring boot', 'j2ee'],
    'laravel developer': ['laravel'],
    'low_code_no_code_development': [
    'outsystems developer',
    'outsystems','Appian Developer'],
    'data analytics': ['data analytics', 'data analyst', 'data analysis', 'data analystics', 'analytics', 'business intelligence', 'bi developer', 'power bi', 'tableau', 'data visualization', 'revenue analyst','analyst  data','data production analyst','knowledge analyst','rfi analyst','pricing actuarial analyst','bi analyst','digital analyst','data quailty  analyst','Data Strategist',' analyst'],
    'marketing related jobs': ['marketing manager', 'brand manager', 'digital marketing manager','marketing','marcom'],
    'mobile developer': ['ios developer', 'android developer', 'mobile developer', 'flutter', 'react native','android','ios','apps developer','mobile app','VoltMX','Kony'],
    'microsoft apps':['power apps','microsoft','ms exchange engineer','SharePoint Developer','share point Developer','SharePoint '],
    'mis specialist': ['mis specialist'],
    'ms sql engineer': ['ms sql', 'ms sql engineer', 'sql server'],
    'magento developer':['magento'],
    'network engineer': ['network engineer', 'network administrator', 'network specialist', 'cisco', 'ccna', 'ccnp','information systems security analyst','routing '],
    'php developer': ['php', 'laravel', 'codeigniter'],
    'product owner': ['product owner'],
    'project coordinator': ['project coordinator', 'project lead', 'assistant project manager'],
    'project manager': ['project manager', 'projects manager', 'tech pmo', 'planner','Cost Control Engineer','Backlog Conversion','Implementation Officer','product manager','Program Manager'],
    'python developer': ['python', 'django', 'flask'],
    'react developer': ['react'],
    'social media related jobs':['media','content','editor'],
    'sales manager': ['sales manager', 'account executive', 'sales executive', 'business development manager'],
    'scrum master': ['scrum master'],
    'sap related jobs':['sap dev','sap prog','SAP','sap manager'],
    'software architect': [
        'solution architect', 'software architect', 'it architect', 'technical architect','SOA Developer','application architect',' architect','architect ',' architect '
    ],
    'software developer': [
        'software developer', 'software development', 'software solution', 'AV programmer','system developer','programming developer','Desktop Developer','Vue.js Nuxt.js','App Connect Developer','C++ Developer'
        ,'POS ','bashshell developer','c developer','Interoperability Developer'
    ],
    'software implementation engineer': [
        'software implementation engineer', 'software implementation'
    ],
    'software analyst': [
        'software analyst', 'support analyst'  # Standardized capitalization
    ],
    'software tester': [
        'tester', 'testing', 'quality', 'test automation engineer','test automation','test resource','test','Test Automation','Quality Manager'
          ,'quality assurance', 'automation testing', 'qa tester', 'test engineer','qa engineer','qa manager'
            ,'quality control', 'qc testing', 'qc inspector', 'test engineer','qc engineer','qc manager','audit'
              ,'verification   validation','verification engineer','validation engineer','Digital Assurance'
                ,'pqcs ','qa automation'  # Added 'software tester' for clarity
    ],
    'software engineer': [
        'software engineer', 'it engineer', 'computer engineer', 
        'Sr. CAM programmer', 'programmer','program developer'
        ,'integration developer','Software Integration','Application Engineer'  # Standardized "Sr. cam programmer" to "Sr. CAM programmer"
    ],
    'system administrator': [
        'sysadmin', 'system admin', 'server administrator', 
        'it administrator', 'admin services  analyst','systems administrator','system administrator'
          ,'Linux Software Expert','Applications Specialist'  # Standardized spacing in 'admin services  analyst'
    ],
    'system engineer': [
        'system engineer', 'systems engineer'  # No changes needed
    ],
    'system analyst': [
        'system analyst', 'systems analyst', 'technical analyst'  # No changes needed
    ],
    'technical customer success specialist': [
        'technical customer success specialist', 'technical customer support'
    ],
    'technical specialist': [
        'technical data specialist','CCS Technology Development ','Technology Development Specialist'
        ,'Technology Deployment Expert'
    ],
    'technical manager': [
        'technical manager', 'it manager', 'tech manager', 'supervisor', 
        'cto', 'ceo', 'chief','IT Systems Manager','Principal Technologist',
        'team lead', 'team leader', 'tech lead', 'project lead','it head','lead','head of','Application Section Head',' Head '  # Titles like 'cto', 'ceo', and 'chief' might need further categorization (see notes).
    ],
    'technical office related jobs': [
        'technical office'
    ],
    'technical support engineer': [
        'technical support', 'hvac technician', 'technician fabricator', 
        'technical surveyor', 'o m expert', 'technician expert', 
        'laptop technician', 'ca technician', 'technology technician', 
        'technical evaluator', 'transformer expert', 'support engineer','Computer Technician'
    ],
    'technical writer': [
        'technical writer'
    ],
    'wordpress developer': ['wordpress'],
    'odoo related jobs':['odoo','oodo'],
    'operations related jobs': ['operations','operation','operator', 'associate or associate'],
    'zoho implementation specialist': ['zoho implementation specialist'],
    'manager related jobs': ['manager', 'management'],
    'consultant related jobs': ['consultant','process transformation','Visiting Associate'],
    'business tech jobs':['business ','business']
       
}


def handle_jobs(job_title,replace,mapping):
    keys=mapping.keys()
    job_title = job_title.lower()
    for old,new in replace:
        job_title = job_title.replace(old,new).strip()
    
    for modefied_job_title,mapped_v in mapping.items():
        if job_title not in keys :
            if any(one.lower() in job_title for one in mapped_v):
                job_title = modefied_job_title
        
    return job_title.strip()

all_df['job_title'] = all_df['job_title'].apply(lambda x: handle_jobs(str(x),general_replacements,job_mappings))

# %%
print('before')
print(len(all_df))

all_df = all_df[~all_df['job_title'].str.contains('call center', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('sales', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('marketing', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('content', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('customer service', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('housekeeping', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('digital', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('customer support', na=False, case=False)]
all_df = all_df[~all_df['job_title'].str.contains('client support', na=False, case=False)]


print('after')
print(len(all_df))
# Out:
# before
# 3685
# after
# 3675

# %%
len(job_mappings.keys())
# Out:
# 103

# %% [markdown]
# #### Group developers working with rare languages or frameworks under the "special_development" category

# %%
job_titles_change=all_df[all_df['job_title'].str.contains('developer',case=False)]['job_title'].value_counts()

job_titles_change_1=job_titles_change.index[17:]
all_df.loc[all_df['job_title'].isin(job_titles_change_1),'job_title'] = 'special_development'

# %% [markdown]
# #### Remove jobs that cannot be grouped according to our job mapping criteria

# %%
print('before')
print(len(all_df))

job_titles_delete=all_df['job_title'].value_counts()[80:].index

all_df=all_df[~all_df['job_title'].isin(job_titles_delete)]

all_df.reset_index(drop=True,inplace=True)

print('after')
print(len(all_df))

print(f"now the length of unique values for the jobt title is {len(all_df['job_title'].unique())}")
# Out:
# before
# 3675
# after
# 3518
# now the length of unique values for the jobt title is 80

# %% [markdown]
# #### Perform manual analysis to ensure that the 80 selected groups accurately contain jobs relevant to them.

# %%
all_df[all_df['job_title'] == 'information security engineer']['job_title_basic'].unique()
# Out:
# array(['Information Security Engineer',
#        'Information Security Section Head',
#        'Senior Specialist - Information Security',
#        'Information Security Team Leader - GRC',
#        'Information Security Specialist.',
#        'Information Security Specialist',
#        'Information Security Administrator',
#        'Information Security Officer',
#        'Senior Information Security Engineer',
#        'Senior Information Security Consultant',
#        'Information Security Analyst',
#        'Information Security Controls Officer/Senior Officer',
#        'Information Security Compliance Officer/Senior Officer',
#        'Info Security Sr Analyst', 'Info Security Assoc Manager',
#        'Chief Information Security Officer',
#        'Senior Information Security Consultant Immediate',
#        'Information Security Manager', 'Information Security Consultant',
#        'Head of Information Security', 'Information Security Team Leader'],
#       dtype=object)

# %% [markdown]
# #### now make more general 10 groups so make it easy for the end user to reach its nead

# %%
job_categories = {
    "Project Management and Leadership": [
        "Project Manager", "Scrum Master", "Product Owner", "Technical Manager",
        "Manager Related Jobs", "Director Related Jobs", "Executive Related Jobs",
        "Coordinator Related Jobs"
    ],
    "Software Development": [
        "Mobile Developer", "Software Engineer", "Dot Net Developer", "Software Developer",
        "Java Developer", "Application Developer", "Front End Developer", "Python Developer",
        "Full Stack Developer", "Backend Developer", "Embedded Developer", "PHP Developer",
        "Angular Developer", "React Developer", "Laravel Developer", "Game Development Jobs",
        "Low Code/No Code Development", "Developer"
    ],
    "IT Support and Help Desk": [
        "IT Help Desk", "IT Support", "Technical Support Engineer", "IT Specialist",
        "Application Support", "IT Back Office"
    ],
    "Network and Security": [
        "Network Engineer", "Network Security Engineer", "Information Security Engineer",
        "Cyber Security Engineer", "Infrastructure Engineer", "IT Infrastructure"
    ],
    "Database and Systems": [
        "Database Administrator", "Database Developer", "System Administrator", "System Engineer",
        "System Analyst", "Information System Engineer"
    ],
    "Cloud and DevOps": [
        "Cloud Engineer", "DevOps Engineer"
    ],
    "Specialized Software and Applications": [
        "WordPress Developer", "Oracle Related Job", "Odoo Related Jobs", "SAP Related Jobs",
        "Microsoft 365", "Microsoft Apps", "ERP Related Job", "CRM Related Jobs"
    ],
    "Data and Analytics": [
        "Data Analytics", "Data Engineer", "Data Scientist", "Data Governance", "FP&A Analyst"
    ],
    "Design and Development": [
        "Designer", "Special Development"
    ],
    "Miscellaneous and Support Roles": [
        "HR Specialist", "Business Tech Jobs", "Business Analyst", "Consultant Related Jobs",
        "Operations Related Jobs", "Account Manager", "Instructor", "Technical Specialist",
        "Technical Office Related Jobs", "Intern", "Associate"
    ]
}
def big_group_handle(job_title,job_dic):
    job=job_title.lower()
    for i,l_v in job_dic.items():
        if any(v.lower() in job for v in l_v):
            return i
all_df['job_groups']=all_df['job_title'].apply(lambda x:big_group_handle(str(x),job_categories))

# %%
all_df['job_groups'].unique()
# Out:
# array(['Project Management and Leadership', 'Software Development',
#        'IT Support and Help Desk', 'Network and Security',
#        'Specialized Software and Applications', None, 'Cloud and DevOps',
#        'Design and Development', 'Database and Systems',
#        'Data and Analytics', 'Miscellaneous and Support Roles'],
#       dtype=object)

# %% [markdown]
# ### handle he skills column

# %%
# discover the skills that related to some groups
all_df[all_df['job_groups'] == 'Software Development']['skills'].unique()
# Out:
# array(['flutterdeveloperFlutter developerSoftware DevelopmentComputer ScienceSoftware',
#        'AdministrationIT/Software Development',
#        'Communication skillsCommunicationCommunication EngineeringCommunications EngineeringComputer ScienceComputer ProgramsComputer EngineeringComputer SystemsInformation SystemsInformation Technology (IT)JavaScriptGraphic DesignDesignWordPressPHPHTMLTroubleshootingSEOCSS',
#        'Information Technology (IT)OracleSoftware DevelopmentOracle Forms',
#        'AgileASP.Net.NetInformation Technology (IT)Software DevelopmentSQLRESTful',
#        'Backend developerbackendComputer ScienceInformation Technology (IT)developerseniorSoftware DevelopmentSoftware Engineering',
#        '.NetSoftware EngineeringAgileComputer ScienceSoftware DevelopmentAngular2SQL',
#        'Information Technology (IT)JavaSoftwareLinuxMySQLSoftware DevelopmentPHPEngineeringDesignDevelopmentSpring Boot',
#        'Application DevelopmentASP.Net.NetComputer ScienceGitEngineeringInformation Technology (IT)Software DevelopmentMVCJSONSoftware EngineeringSQL',
#        'AngularIonicInformation Technology (IT)DevelopmentComputer Sciencefront-end',
#        'AWSAPIsRESTfulPythonSoftware EngineeringComputer ScienceDesignGitInformation Technology (IT)MySQLProgrammingReactRESTSoftware Development',
#        'AgileAndroidComputer ScienceGitInformation Technology (IT)MVCSoftwareJavaSoftware EngineeringUIKotlin',
#        'computerComputer ScienceEnglishInformation technologySoftware EngineeringSoftware DevelopmentTechnical SupportInformation Technology (IT)SQLMicrosoft SQL ServerERP Software',
#        'Computer ScienceInformation Technology (IT)JavaScriptSoftware DevelopmentReact.jsnext.jsfrontendsoftwareweb',
#        'MobileAndroidFlutteriOS Development',
#        'Computer ScienceEngineeringPythonDockerNode.jsBackend EngineeringSoftware DevelopmentSoftware Engineering',
#        'Node.jsReact.jsFull Stack Development',
#        'Computer ScienceEngineeringInformation Technology (IT)Software DevelopmentPythonDjango',
#        'AgileAngularComputer ScienceDevelopmentInformation Technology (IT)ManagementSoftware EngineeringNode.jsProject ManagementqualitySoftwareSoftware DevelopmentEducational Technology',
#        '.NetComputer ScienceSoftware EngineeringSoftware DevelopmentSQLWeb DevelopmentInformation Technology (IT)JavaScriptXMLHTML',
#        'AgileInformation Technology (IT)ProgrammingSoftware DevelopmentTroubleshootingWeb DevelopmentReactJavaScriptComputer ScienceOOPDesign',
#        'AndroidiOSflutter.NetMobile Development',
#        'Android.NetASP.NetComputer ScienceInformation Technology (IT)ProgrammingJavaScriptDevelopmentSoftware DevelopmentSQLSoftware EngineeringSoftwarec#',
#        'Computer ScienceFull StackHTMLCSSERPjQueryPHPCMSMySQLFront EndBack EndJavascriptEnglishSoftware DevelopmentBack-End DevelopmentFront-End Development',
#        'Embedded CEmbedded Systems',
#        'LaravelPHPSEODevelopmentComputer ScienceInformation Technology (IT)',
#        '.NetComputer ScienceEngineeringSQLSoftware Engineering',
#        '.NetAngularComputer ScienceCSSEngineeringHTMLInformation Technology (IT)JavaScriptjQuerySoftware DevelopmentSQLMySQL',
#        'React NativeReactReduxC Sharp',
#        'Full Stack DeveloperdeveloperComputer ScienceJavaScriptInformation Technology (IT)Full StackAngularCSSHTMLJava',
#        'Node.jsMongoDBbackendComputer ScienceDesignDockerFrontendInformation Technology (IT)ProgrammingSoftware DevelopmentSoftware EngineeringUI',
#        'KotlinbackendSoftwarePHPMySQLAWSSoftware EngineeringSoftware Development',
#        'Software DevelopmentComputer ScienceHTMLInformation Technology (IT)jQueryJSONSQLWeb Developmentfront-endJavaScriptAPIsCSS',
#        'AngularAPIsComputer ScienceCSSHTMLInformation Technology (IT)AgileJavaScriptGitMongoDBSoftware DevelopmentNode.js',
#        'AndroidInformation Technology (IT)RESTJSONMaintenanceMobile applicationSoftwareComputer ScienceSoftware DevelopmentSoftware EngineeringTroubleshootingMobile DevelopmentDevelopmentEngineeringGitDatabaseKotlinjetpack compose',
#        'Software DevelopmentInformation Technology (IT)Mobile DevelopmentObjective-CiOSMobile ApplicationsiOS DevelopmentOOPMVCRESTEngineeringComputer ScienceSoftware EngineeringSwiftDevelopmentAPIsProgrammingUIkitswiftui',
#        '.NetAngularComputer ScienceCSSEngineeringHTMLInformation Technology (IT)JavaScriptjQuerySoftware DevelopmentWeb DevelopmentSQL',
#        'Computer ScienceInformation Technology (IT)PHPSoftware DevelopmentLaravel FrameworkLaravel PHP',
#        'IOTEngineeringComputer ScienceInformation Technology (IT)MQTTEmbedded SystemsPythonAzureAWS',
#        'CC++C#Computer ScienceProgrammingSoftware DevelopmentSkills',
#        'Computer ScienceMobile DevelopmentReact NativeiOSExpoAWSjavaScriptNode.jsExpress.jsAndroidGitHubInformation Technology (IT)Software DevelopmentRESTReactNativeGit',
#        'PHPLaravelHTML5MYSQLCSS3JavaScriptJQueryRESTful APIsOOPMVCLaravel PHP DeveloperGitSoftware DevelopmentjQueryComputer Science',
#        '.NetASP.NetSoftwareSoftware DevelopmentSQLMVC',
#        '.NetAngularASP.NetComputer ScienceCSSHTMLInformation Technology (IT)JavaScriptjQuerySoftware DevelopmentSQLWeb Development',
#        'AndroidComputer ScienceSoftware DevelopmentSoftware Engineering',
#        'computerComputer ScienceCustomer ServiceXMLHTMLIntegrationTroubleshootingTechnical Support',
#        'Information Technology (IT)Software DevelopmentSoftware EngineeringOOPASP.NETC#.NetADO.NETSQLMySQLjavaScriptQueryHTMLCSSjQueryAngularMSSQLOOAD.NETMVCC#HTML5Computer ScienceComputer EngineeringAngularJSAngular4Angular2Angular 8.NET 4.5EngineeringAngular 8+ASP.NET Core3/N-Tier Architecture',
#        'Node.jsMySQLREST',
#        'Computer ScienceEngineeringFull StackSoftware DevelopmentHTML5Information Technology (IT)GitJavaScriptMySQLPHPReactCSS3',
#        'Computer ScienceFull StackdeveloperFull Stack Developersenior',
#        '.Net FrameworkC#Computer ScienceSoftware DevelopmentInformation Technology (IT)JIRASoftware EngineeringAgileSQLReact',
#        'Information Technology (IT)Computer Science',
#        'PHPAPIsAgileHTML5MySQLSoftware EngineeringJavaScriptSoftware Development',
#        'Reactreact frontendfrontend developerComputer ScienceAngularSoftware DevelopmentCSSHTMLInformation Technology (IT)JavaScriptVue',
#        'developerlaravel developerComputer ScienceInformation Technology (IT)PHPLaravel',
#        'Computer SciencedesktopdeveloperInformation Technology (IT)seniorSoftware DevelopmentSoftware EngineeringSQLSoftwareProgrammingOOPGitEngineering',
#        'JavaScriptAngularComputer ScienceJavaMySQLInformation Technology (IT)PostgreSQLSoftware DevelopmentSpringHibernateAzureAWS',
#        'Mid-Senior Laravel FullStack DeveloperLaravel frameworkVue.jsGraphQLSoftware TestingPHPMVCObject-Oriented ProgrammingSQL DatabaseMySQLquery languagesAlgorithmsGitRESTful APIssoftware design patternssoftware architectural patternsCI/CDTDDInformation Technology (IT)ProgrammingSoftware',
#        'Androidback-endAPIscomputerComputer ScienceInformation Technology (IT)Offline storageRESTfulRESTful APIsSoftware DevelopmentSoftware EngineeringThreadingEnglishCommunicationTroubleshootingMobile DevelopmentSoftwareJavaXML',
#        'EngineeringComputer ScienceInformation Technology (IT)OracleSQLAsp.NetMVCHTML5CSSAJAXjQueryjavaScriptXMLAngularJSASP.NETWeb DevelopmentWeb Design.NETAngularjsAngular 6HTMLJavaScriptCSS3WireframesVisual DesignGITVSTSC#',
#        'C#Information Technology (IT).NETMVCASP.NETcoreSoftware DevelopmentComputer SciencejavaScriptSQLHTML5AgileSoftware Engineering',
#        'AgileAngularfront-end', 'PHPWeb DevelopmentMVCLaravel',
#        'codingComputer ScienceHTMLSoftware DevelopmentWeb DevelopmentWebsitesCSS',
#        'Computer ScienceHTMLLaravelMySQLPHPSoftware DevelopmentSoftware EngineeringjQueryJavaScriptInformation Technology (IT)CSSGit',
#        'Computer ScienceDesignEngineeringInformation Technology (IT)Software DevelopmentSoftware Engineering',
#        'Software DevelopmentArtificial Intelligence (AI)process automation',
#        '.NetAngularEngineeringSQLSoftware DevelopmentComputer ScienceASP.NetHTML5Full Stack',
#        'AlgorithmsComputer ScienceInformation Technology (IT)Software EngineeringSoftware DevelopmentProgrammingPythonDatabaseReactJavaScriptTypescriptCommunicationFrameworksCloudMicroservices',
#        'Full StackNode.jsReactReact.jsNext.jsSoftware DevelopmentAPIsGitNoSQLRESTfulInformation Technology (IT)JavaScriptComputer Science',
#        'AngularComputer ScienceCSSFull StackJavaScriptjQueryMVCSoftware DevelopmentSQLHTMLEngineeringInformation Technology (IT)Winformshardware-integrationPythonembedded inferenceArduino, ESP32, Rockchip',
#        'Full StackAngularComputer ScienceCSSHTMLInformation Technology (IT)JavaScriptjQueryMySQLSoftware DevelopmentSoftware EngineeringSQLDockerNode.jsPython',
#        'GitCSSHTMLVue.js', 'Node.jsReact.jsnextnest.jsMySQLMongoDB',
#        'LaravelSoftware Development',
#        'HTMLwebsiteWordPressexcel formulasTechnical SupportWooCommerceWordPress DevelopmentCSSInformation Technology (IT)Computer Science',
#        'Vue.jsVue,jsJavaScriptNuxtFrontend',
#        'software developerSoftwaredeveloperComputer ScienceSoftware DevelopmentSoftware EngineeringMySQLPHP DevelopmentPHPJavaScriptpython developmentCSSHTMLAI',
#        'javaScript FrameworksReactdotNet.Net FrameworkFront-End DevelopmentFull Stack Development',
#        'HTML5HTMLJavaScriptPHPSoftware DevelopmentComputer ScienceInformation Technology (IT)SQLCSSjQueryMVCMySQL',
#        'Full Stack DevelopmentAngularJavaJavaScriptCI/CDSpringMicroservicesRESTful APIHTMLCSS',
#        '.NetAngularASP.NetComputer ScienceHTML5Information Technology (IT)JavaScriptjQueryJSONMVCSoftware DevelopmentSQL',
#        'AJAXComputer ScienceDevelopmentHTMLInformation Technology (IT)JavaScriptOraclePHPSOAPSoftware DevelopmentSQLXML',
#        'AzureASP.NetAngular.NetCSSGitHTMLJavaScriptSoftware DevelopmentSQL',
#        'IT/Software DevelopmentEngineering - Telecom/Technology',
#        '.NetNETMVCSoftware Development',
#        'APIsComputer ScienceCSSGitHTMLInformation Technology (IT)JavaScriptReact NativeReactRESTfulSoftware DevelopmentWeb DevelopmentMentoringTeam Leadershiptesting frameworksSoftware TestingECMAScript (ES6)Optimize frontend codecode reviewGraphQLJestJasmineMochaWeb Securitylazy loadingmobile-friendly web interfacesReact.js',
#        'StartupReact.JSSoftware DevelopmentJavaScriptRESTful APIsReactReduxComputer ScienceInformation Technology (IT)JSONRESTfulJsFront Endfront-endDevelopment',
#        'Computer ScienceComputer EngineeringInformation Technology (IT)ASP.NETASP.NETMVCJSONHTMLGitC#LINQCSSjavaScriptSQLSoftware DevelopmentjQuery',
#        'Python DjangoContinues Integration (CI)Continuous Delivery (CD)DevOpsGithub ActionsDockerOracle Cloud Infrastructure (OCI)AWSTerraformAgileMySQLComputer ScienceUnit TestingTeam LeadershipELKCybersecurityFintechMicroservice Architecture',
#        'APIsComputer ScienceCSSEngineeringGitHTMLInformation Technology (IT)JavaScriptProgrammingSoftwareReactSoftware DevelopmentJavaNode.jsFront Office ManagementFront-End Developmentfront-end web developmentFrontEndFront End',
#        'CSS3HTMLHTML5JavaScriptjQueryWordPressGitAmazon AWSXml Web ServicesJSONComputer Science',
#        'ASP.NETADO.NETC#.Net.NET.NEt Full Stack DeveloperFull Stack DeveloperjavaPythonHTMLMS SQLMongoDBUI/UX designAngularFull StackComputer ScienceApacheUIUXMySQLOracleCSSJavaScriptJavaC#Software DevelopmentSoftware EngineeringSoftwareInformation Technology (IT)SQLAgileMicroservice ArchitectureRabbitMQ',
#        '.Net.Net FrameworkInformation Technology (IT)SQLAngularComputer ScienceSoftware DevelopmentFull Stack Development',
#        'ASP.NETInformation Technology (IT).NETjQuerySoftware DevelopmentComputer SciencejavaScriptC#Computer EngineeringTFSHTMLAPIRESTRPCASP.NET MVCEnglishASPSoftware Engineering',
#        'Computer ScienceInformation Technology (IT)Software DevelopmentSoftware EngineeringPHPjavaScriptLaravelMySQLBack-EndWeb DevelopmentGitCSSSoftware',
#        'LaravelFull StackSoftware DevelopmentPHPMySQLAPIsRESTfulComputer ScienceBootstrapVueSoftwareJsVue.jsInformation Technology (IT)Development',
#        'ReactAngularfront-endSoftware DevelopmentGit',
#        'AngularComputer Sciencefront-endHTMLJavaScriptReactSoftware Development',
#        'back-endComputer ScienceHTMLInformation Technology (IT)PHPSoftware DevelopmentSoftware EngineeringWeb DevelopmentJavaScriptfront-end',
#        'ASP.NETSoftware Development.NETInformation Technology (IT)Full StackComputer ScienceComputer EngineeringDatabase DesignData ModelingProcess ModelingERPDFDC#CSS3javaScriptHTML5jQueryAngularADO.NETEntity FrameworkSOLIDSolidWorks',
#        'AngularComputer ScienceInformation Technology (IT)JavaMongoDBPHPReactSoftware DevelopmentMySQL',
#        'DesignInformation Technology (IT)PHPProgrammingJavaScriptSQLHTMLWordPressUXuiCSSComputer Science',
#        'blazorMVCASP.NET Corec#.netASP.net MVC 5',
#        'nextReact.jsfrontendWeb Development',
#        'PHPInformation Technology (IT)LaravelSoftware DevelopmentEngineering',
#        '.NetAngularASP.NetMVC',
#        'Senior Frontend DeveloperVue.js / Vue 3JavaScript / TypeScriptRemote WorkCSS3HTML5SassCRM Software DevelopmentComputer ScienceCSSAgileJavaScriptSoftware DevelopmentHTMLGitSoftware EngineeringNuxtJs',
#        'Computer ScienceDevelopmentInformation Technology (IT)JavaScriptSoftwareSoftware DevelopmentFront-End DevelopmentAngular',
#        'Computer ScienceInformation Technology (IT)flutterSoftware Development',
#        'APIsbackendEngineeringAWSGitMySQLPythonDjango FrameworkPostgreSQLRESTful APIsSQL',
#        'CSSJavaScriptjQueryMVCAngularSQLSoftware DevelopmentASP.Net.NET Core MVC',
#        '.NetSoftware DevelopmentSQLInformation Technology (IT)Computer ScienceWeb DevelopmentHTML5ASP.Net',
#        'Information Technology (IT)DevelopmentSoftware DevelopmentComputer Sciencefront-endHTML5JavaScriptASP.NetCSSAngularAPIs.Net',
#        'PHPReact.jsVue.jsMagentoCSSMySQLGraphQLJSDevelopmentfull-stackShopifyJavaScriptLaravel',
#        'Node.jsReact NativeJavaScriptjQuery',
#        'ReactTypescripttailwindReduxComputer ScienceInformation Technology (IT)CSSAgileSoftware DevelopmentDockerJavaScriptEngineeringAPIs',
#        'developerDjangoDjango DeveloperInformation Technology (IT)Software DevelopmentComputer ScienceRemotePython',
#        'Computer ScienceSoftware DevelopmentPython',
#        'Back EndJavaScriptJavaComputer ScienceSpring BootPostgreSQLSQLRESTful APIsGitSOLID OOP Principles',
#        'Full Stack DeveloperJavaScriptAPIsSoftware DevelopmentHTMLCSSMySQLReactRESTSQLAngularComputer Science',
#        'Information Technology (IT)Software DevelopmentjavaScriptReact NativeAndroidReactComputer ScienceDesignAPIsAgileGitRESTJira',
#        'APIsComputer Science.NetInformation Technology (IT)Software DevelopmentSoftware EngineeringSQLASP.NET CoreRESTfulSDLCEntity FrameworkRedisRabbitMQDockerMicrosoft Azure',
#        'back-endComputer ScienceDevelopmentEngineeringInformation Technology (IT)Full-StackProgrammingSoftware DevelopmentWeb DevelopmentSoftwareWeb',
#        'Computer ScienceInformation Technology (IT)javaScriptCSSCSS3Software DevelopmentAngular2+AngularSassUIDevelopmentOOPRESTAPIsSEOfront-endHTML5',
#        'Information Technology (IT)JavaOOPComputer ScienceDevelopmentSpring Bootspring FrameworkSOAPRESTjBPMSQLSoftware ArchitectureFinancial ServicesAngularHTMLJavaScriptCSS3Software DevelopmentDesignEngineering',
#        'Computer ScienceFull StackFull Stack DeveloperseniorSoftware DevelopmentStackInformation Technology (IT)Angular.Netfront-endSoftware',
#        'bootComputer SciencedeveloperFrameworkInformation Technology (IT)JavaJava webSoftware DevelopmentSpringWebweb developerWeb DevelopmentComputer EngineeringCSSEngineeringHTMLJavaScriptRESTfulSQL',
#        'Software DevelopmentComputer Science',
#        'PHPDevelopmentJavaScriptSoftware DevelopmentWebLaravel FrameworkAPI',
#        'backendBackend developerComputer ScienceSoftware DevelopmentSoftware EngineeringdeveloperNode.jsAPIAPIsGitInformation Technology (IT)JavaScriptMongoDBMySQLRESTful',
#        'JavaJavaScript',
#        'Java Spring BootJavaSoftware DevelopmentITSoftware EngineeringInformation Technology (IT)Computer Science',
#        'developerJavaseniorJava DeveloperSoftware DevelopmentSoftware Engineering',
#        'BootstrapComputer ScienceDevelopmentInformation Technology (IT)HTML5CSS3AgileNodeJSPHPJavaScriptSoftware DevelopmentSoftware Engineering',
#        'Computer ScienceInformation Technology (IT)InsuranceJIRALeadsHybridMedicalseniorPythonSoftware DevelopmentSoftware Engineering',
#        'PHPComputer ScienceLaravelHTML5CSS3MVCProgrammingjavaScriptInformation Technology (IT)ServersGitFront-EndSoftware DevelopmentSoftware Engineering',
#        'Information Technology (IT)CSSjavaScriptHTML5VueCSS3ReactSASSLESSComputer ScienceDevelopmentSEOEngineeringSoftware DevelopmentComputer EngineeringFlutterReact NativeSoftware Engineering',
#        '.NetAngularInformation Technology (IT)OOPJavaScriptComputer Science',
#        'AndroidMobile ApplicationsMobile AppAPISoftware DevelopmentSoftwareIOTInformation Technology (IT)ITIDesignComputer ScienceComputer EngineeringAndroid EngineeringAndroid SDKRESTful APIsAndroid UISDKMobile DevelopmentSoftware EngineeringUIRESTEngineeringAPIs',
#        'Computer ScienceDevelopmentCSS3HTML5Information Technology (IT)Software DevelopmentWordPressSoftware Engineering',
#        'Electrical EngineeringEngineeringengineersmart homessmartInformation Technology (IT)AutomationInstallationKNXHome AutomationSmart Home',
#        'Back-End Developerback-endPHPPHP FrameworkdeveloperFrameworkSymfonySymfony Framework',
#        'PHPLaravelLeadershipSymfonySymfony FrameworkInformation Technology (IT)Software DevelopmentSoftware Engineering',
#        'Full StackComputer ScienceSoftware Development',
#        'Full StackFull Stack DeveloperInformation Technology (IT)PHP LaravelLaravelComputer SciencedeveloperStack',
#        '.NetADO.NetASP.NetComputer ScienceInformation Technology (IT)jQueryJSONOOPSoftware DevelopmentSQLWeb DevelopmentASP.NET Web Formsc#',
#        'HTMLCSSjQueryJavaScriptRESTfulBootstrapUI DeveloperUI',
#        'AngularComputer ScienceCSSEngineeringHTMLInformation Technology (IT)JavaScriptMySQLPHPSoftware DevelopmentSoftware EngineeringSQL',
#        'AngularComputer ScienceInformation Technology (IT)React NativeReactSoftware DevelopmentEngineeringSoftware Engineering',
#        'Computer ScienceDynamicsInformation Technology (IT)EngineeringJavaScriptHTMLMicrosoftSoftware DevelopmentCSS',
#        'C#EngineeringComputer ScienceProgrammingElectronics.NETSoftware DevelopmentProblem SolvingInformation Technology (IT)Winforms',
#        'Computer ScienceEnglishHTMLGitXMLSoftware DevelopmentInformation Technology (IT)Software EngineeringJIRAJavaAndroidKotlinJetpack composeAndroid DevelopmentAndroid Application DevelopmentAndroid OSAndroid SDKAndroid ProgrammingAndroid Application',
#        'IT/Software Development',
#        'Computer ScienceSoftware EngineeringInformation Technology (IT)Mobile DevelopmentSoftware DevelopmentgoogleAPIMobileUXuiEngineeringDesign',
#        'AngularComputer ScienceFrontendHTMLGitInformation Technology (IT)Software DevelopmentSoftware EngineeringCSSDesignuiUX',
#        'AngularIonicJavaScript',
#        'AngularPHPMySQLNode.jsAngular.jsLaravel PHPSoftware DevelopmentInformation Technology (IT)GitRESTAPI DevelopmentSOAPEngineeringSoftwareComputer Engineering',
#        'MongoDBCSS3Node.jsReact',
#        'Software DevelopmentSoftwareSoftware EngineeringComputer ScienceDevelopmentPythonAngularAWSEngineeringInformation Technology (IT)TestingTroubleshooting.Net Framework',
#        'Information Technology (IT)Computer ScienceProgrammingSoftware.Net',
#        'JavaScriptjavascript developerFront-End Development',
#        'backendDevelopmentPHPLaravelSoftware DevelopmentSoftwareInformation Technology (IT)',
#        'Information Technology (IT)Computer ScienceSoftware Development.NETC#ASP.NETjavaScriptComputer EngineeringHTMLEngineeringCSSSoftwareSoftware EngineeringArabicEnglishAngularblazorDatabaseSQLDevelopmentAgileMVC',
#        'ProgrammingSoftware DevelopmentComputer Sciencemobile applicationInformation Technology (IT)backend',
#        'Information Technology (IT)flutterSoftware EngineeringIT Service ManagementIT fieldSoftware DevelopmentBLOcCubitGitflutter web',
#        'Information Technology (IT)Computer ScienceDevelopmentSoftware EngineeringERPOracleSoftware Development.Net DevelopmentBack-End DevelopmentC#',
#        'Software DevelopmentjQueryComputer ScienceWeb DevelopmentSQLInformation Technology (IT)SoftwareMVCJavaScriptCSS.Net',
#        'Business ProcessesBusiness Requirement DocumentApplication Development',
#        'Computer ScienceAndroidMac OSSoftwareSoftware EngineeringInformation Technology (IT)computerEngineeringScienceSoftware DevelopmentMobile DevelopmentDevelopmentbackend',
#        'EngineeringAPIsPHPBack-End DevelopmentFull Stack DevelopmentComputer ScienceInformation Technology (IT)MVCSoftwareSoftware Developmentphalcon',
#        'JavaSoftware Development',
#        'iOSObjective-CInformation Technology (IT)AgileAPIsComputer ScienceCore DataCore AnimationSoftware DevelopmentGitEngineeringSwift',
#        'AndroidAPIsComputer ScienceDevelopmentflutterEngineeringDesignInformation Technology (IT)JSONMobile DevelopmentRESTfulGit',
#        'HTMLInformation Technology (IT)DesignCSSComputer ScienceDevelopmentSoftware DevelopmentPHPSoftwareJavaScriptEngineeringcodingBackendLaravel',
#        'App connectdeveloperSoftware Development',
#        'Computer Sciencefront-endInformation Technology (IT)JavaScriptReactSoftware DevelopmentCSS3',
#        'APIsComputer ScienceCSS3GitHTML5Information Technology (IT)jQueryJavaScriptMySQLPHPSoftware DevelopmentSoftware Engineering',
#        'AWSFull Stackfront-endSoftware DevelopmentIonic FrameworkIonicVue.jsBack-End DevelopmentGitTypescriptAPIAPIsComputer ScienceDevelopmentInformation Technology (IT)JavaScriptMongoDBMySQLSoftware',
#        'JavaKotlinjetpackMVVMMVPMVCSoftware DevelopmentAndroidComputer scienceAPIsJSONRESTMobile DevelopmentPostmanFirebaseRESTful APIsGitGithubAndroid SDKFlutter',
#        'iOSSwiftObjective-C', 'Android SDKJSONKotlin',
#        'NextJSReactFullstackJavaScriptSoftware DevelopmentfirebaseJavaScript DevelopmentDevelopment',
#        'HTMLInformation Technology (IT)JavaScriptFull StackWeb DevelopmentOOPjQueryCSSPythonBootstrapComputer ScienceSoftware Development',
#        'EngineeringAPIsLaravelPHPBack-End DevelopmentFull Stack DevelopmentComputer ScienceInformation Technology (IT)MVCSoftwareSoftware Development',
#        'GolangFull Stack DevelopmentTeam LeadershipProblem SolvingAPIsAWSbackendComputer ScienceDevelopmentDockerInformation Technology (IT)JavaScriptGitNoSQLSoftware DevelopmentSoftware Engineering',
#        'ReactAPIsGitJavaScriptMobile DevelopmentSoftware DevelopmentRESTful APIsReact NativeTypescriptAndroidiOS',
#        '.net DeveloperComputer ScienceInformation Technology (IT)developer.NetSoftware Development',
#        'Computer ScienceSoftware DevelopmentInformation Technology (IT)Software EngineeringMVCEngineeringGitPHPHTML5TroubleshootingFront-EndOOPSW DevelopmentDevOpsDatabaseLaravelBack-End Development',
#        '.NetComputer ScienceAgileAngularDesignEngineeringGitInformation Technology (IT)MVCSoftwareSoftware DevelopmentSQLElectron . NET',
#        'FrontendReactSoftware DevelopmentJavaScriptInformation Technology (IT)AgileComputer ScienceHTMLRESTfulGitCSSAPIs',
#        'JavaScriptSoftwareComputer EngineeringComputer SciencePythonSoftware DevelopmentInformation Technology (IT)DjangoHTMLCSSjavaScriptMSSQLNoSQLCloud PlateformsDockerweb servicesAPI Development',
#        'AngularComputer ScienceHTML5FrontendJavaScriptPHPSoftware DevelopmentjQueryInformation Technology (IT)CSS3',
#        'PHPLaravelHTML5CSS3Computer ScienceSoftware EngineeringJavaScriptSoftware DevelopmentInformation Technology (IT)',
#        '.NetCQRSAzure CloudRabbitMQDomain Driven DesignAzureMicrosoft AzurePostgreSQLORMRESTful APIsSoftware DevelopmentASP.NetEnglishRESTfulAPIInformation Technology (IT)Computer ScienceMVCDevelopmentSoftware Engineering',
#        'Information Technology (IT)Computer ScienceCI/CDbackendAgileFront-End DevelopmentFull Stack DevelopmentTypescriptnextjsReact.js',
#        '.NetCSSHTML5Information Technology (IT)SoftwareSoftware DevelopmentjQueryJavaScriptASP.NetComputer ScienceEngineeringMVC',
#        'AgileProgrammingSoftware DevelopmentAngularComputer ScienceDesignCSSInformation Technology (IT)HTMLSoftware EngineeringJavaScriptGit',
#        '.NetASP.NetComputer ScienceHTMLEngineeringCSSInformation Technology (IT)Software DevelopmentJavaScriptSoftware EngineeringMVCSQL',
#        'Computer ScienceFront endFront end developerAngularCommunication skillsInformation Technology (IT)FrontendAgileSoftware DevelopmentTypescriptC#.Net',
#        'Frontend DeveloperInformation Technology (IT)developerComputer ScienceJavaScriptSoftware Development',
#        'Angular.NetComputer ScienceInformation Technology (IT)SQLSoftware Development',
#        'BootstrapComputer ScienceCSS3ES6GitHTML5Information Technology (IT)JavaScriptJsReactReact.jsSoftware DevelopmentNext.js',
#        'Computer ScienceInformation Technology (IT)Software DevelopmentSoftware Engineering.net coreASP.NetCSSDatabaseEntity FrameworkRedisMicroservicesAngularRabbitMQ',
#        'Computer ScienceLaravelseniorSoftwaresoftware developerInformation Technology (IT)',
#        'EnglishPythonSoftware DevelopmentSoftware EngineeringSoftwareComputer ScienceUXDesign',
#        'wordpressPHPjQueryMySQLBootstrapComputer ScienceCSSFrameworksHTMLInformation Technology (IT)JavaScript',
#        'Angular 17Angular 18Information Technology (IT)ABP',
#        'AgileDevelopmentGraphQLGitReactScrumJavaScriptComputer ScienceHTMLGithubInformation Technology (IT)Software DevelopmentTelecom Engineering',
#        'AWSMongoDBNestJsMachine Learning',
#        'Information Technology (IT)Computer Science.NetSoftware DevelopmentDesktop DevelopmentHTMLASYNCAzurejQuerySVNERDsGitjavaScript',
#        'C++C#.NETJavaSQLNetworkServer Operating SystemsInformation Technology (IT)Software EngineeringjavaScriptImplementationNetworkingNetworksComputer ScienceTelecommunicationSoftwareSoftware DevelopmentIBMService ManagementEnglishITILBusiness IntelligenceBIComputer EngineeringEngineeringDesign',
#        '.NetASP.NetSoftware.net core',
#        'AngularAPIComputer ScienceCSSCSS3front-endGitHTMLInformation Technology (IT)JavaScriptSoftware DevelopmentUIBootstrapReact',
#        'AndroidAPIsComputer ScienceGitDesignInformation Technology (IT)JavaJSONProgrammingSoftware DevelopmentSoftware EngineeringRESTful APIsAndroid SDKCI/CD pipelines',
#        'Computer ScienceEngineeringInformation Technology (IT)JavaScriptMobileMobile DevelopmentReactReact NativeSoftware DevelopmentWebTypescript',
#        'APIsNode.jsProgrammingRESTfulJavaScriptSoftware DevelopmentAWSAPIComputer ScienceBack-End Development',
#        'React.jsReactfront-endTailwindcss',
#        'Information Technology (IT)Software DevelopmentComputer ScienceAndroidITIRESTfulMVCGitSDKMobile DevelopmentAPIsSoftware EngineeringuiJava',
#        'CSSComputer ScienceJavaScriptSassSoftware Developmentfront-endWeb DevelopmentNode.jsVue.jsDevelopmentdeveloperNuxt',
#        'AngularComputer ScienceCSSDevelopmentfront-endJavaScriptSEOSoftware DevelopmentWeb DevelopmentSoftwareInformation Technology (IT)Design',
#        'APIAngularCSSComputer Sciencefront-endHTMLInformation Technology (IT)Software DevelopmentUIJavaScriptGitCSS3',
#        'PHPAPIsAWSbackendComputer ScienceInformation Technology (IT)Software EngineeringSoftware DevelopmentMySQLMagento',
#        'CommunicationComputer ScienceDatabaseInformation Technology (IT)MicrosoftSoftwareSoftware DevelopmenttroubleshootVisual BasicWritingSoftware Engineering',
#        'AngularComputer ScienceAgileCSSGitHTMLInformation Technology (IT)JavaScriptReactSoftware DevelopmentSoftware EngineeringUI',
#        'Information Technology (IT).NETASP.NETComputer ScienceComputer EngineeringSoftware DevelopmentC#MVCHTMLAngularOOPEngineeringSoftwareSoftware Engineering',
#        'Computer ScienceEngineeringFull StackGitInformation Technology (IT)JavaScriptMySQLPHPReactVue.jsLaravelMongoDB',
#        'AWSJavaEngineeringComputer ScienceInformation Technology (IT)',
#        'Creative/Design/ArtIT/Software DevelopmentEngineering - Telecom/Technology',
#        'LaravelMVCMySQLGitSOLID PrinciplesAWSComputer ScienceCSS3HTML5Information Technology (IT)JavaScriptOOPPHP',
#        'AndroidappComputer ScienceflutterMobile AppNative Android',
#        '.NetProgrammingInformation Technology (IT)Computer SciencetechnicalCSoftware DevelopmentSoftware Engineeringcomputer',
#        'Computer ScienceSoftware DevelopmentInformation Technology (IT)Software EngineeringPHPPythonSoftware',
#        'Information Technology (IT)Computer ScienceEngineeringComputer EngineeringIntegrationSoftware DevelopmentSoftware EngineeringJSONJQueryAJAXjavaScript.NETHTML5CSS3SQLOOPDevOpsCommunications EngineeringElectronicsMechatronicsMVCMicroservicesBootstrap',
#        'WordPressPHPdeveloperInformation Technology (IT)Computer Science',
#        'AgileComputer SciencePHPSoftware DevelopmentWeb DevelopmentCSS3HTML5Information Technology (IT)Software EngineeringJavaScriptGitDesign',
#        'JavaScriptNode.jsSoftware DevelopmentReactComputer ScienceInformation Technology (IT)Software Engineering',
#        'ASP.Net.NetComputer ScienceGitSQLMVC',
#        'APIsflutterGitDevelopmentiOSRESTful APIsRESTfulSoftware DevelopmentAndroidComputer ScienceInformation Technology (IT)Mobile Development',
#        'Full StackHTMLComputer ScienceJavaMySQLSoftware Development',
#        'Computer ScienceProgrammingProject ManagementSoftware EngineeringSoftwareSoftware DevelopmentInformation Technology (IT)LinuxJavaPythonMySQLTesting',
#        'APIsComputer ScienceEnglishInformation Technology (IT)React NativeRESTSoftware Development',
#        'AngularInformation Technology (IT)Computer ScienceProgrammingJavaScriptSoftware Developmentangular17',
#        '.NetAPIsASP.NetComputer ScienceDevelopmentFront endInformation Technology (IT)JavaScriptRESTMVCSoftware DevelopmentSQLSharepointBack-End DevelopmentFront-End Development',
#        '.NetAngularSQLInformation Technology (IT)Computer Science',
#        'AngularComputer ScienceInformation Technology (IT)Software DevelopmentSQLRESTJavaScriptHTML5MVCCSS3',
#        'FlutterAngularDart ProgrammingSpring BootMobile DevelopmentAndroidiOS',
#        'Djangofront-endPythonInformation Technology (IT)Software Development',
#        'Computer ScienceDatabaseDatabase DesignInformation technologyMicrosoft SQL ServerMssqlSoftware DevelopmentSQLdeveloperDesignT-SQLInformation Technology (IT)',
#        'AngularAgileComputer ScienceCSSDesignEngineeringFull StackHTMLGitInformation Technology (IT)JavaScriptSoftware Development',
#        'Computer ScienceSoftware Development',
#        'Computer ScienceInformation Technology (IT)ASP.NetSQLCSS3HTML5JavaScriptjQueryOOPSoftware DevelopmentSOAPAngular',
#        'AngularComputer ScienceCSSFull StackSoftware DevelopmentHTMLInformation Technology (IT)JavaJavaScriptjQueryMySQLReact',
#        '.NetComputer ScienceDevelopmentHTMLJavaScriptProgrammingSoftware DevelopmentWeb DevelopmentASP.NetInformation Technology (IT)',
#        'HTMLCSSJavascriptComputer ScienceInformation Technology (IT)Front-EndWeb DevelopmentAdobe PhotoshopVue.js',
#        'ASP.NETMicrosoft SQL ServerC#Information Technology (IT)Computer ScienceSoftware EngineeringSQLMVC.NETMS SQL ServerASPASP.NET MVCASP.NET MVC,Software Development',
#        'computerComputer ScienceEngineeringSoftware EngineeringSoftwareSoftware DevelopmentInformation Technology (IT)',
#        'Software DevelopmentComputer ScienceJavaScriptSQLSoftware EngineeringHTMLCSS.NetGitSoftware',
#        'DevelopmentComputer ScienceInformation Technology (IT)React NativeSoftware DevelopmentMobile DevelopmentReactRESTSoftwareEngineeringNative',
#        'computerComputer ScienceDevelopmentInformation Technology (IT)LinuxGit',
#        'DesignRESTfulMobile DevelopmentAPIGitSoftware EngineeringUI Design',
#        'React NativeNode.jsTypescriptJavaScriptAWSFull Stack Development',
#        'Laravel FrameworkAPIbackend Developer6th OctoberDatabaseLaravelPHPRESTAPIslivewireInformation Technology (IT)Computer ScienceWeb DevelopmentGitMySQLAWSSoftware Development',
#        'Mobile DevelopmentDesktop ApplicationsSaaSAndroidComputer ScienceInformation Technology (IT)APIsiOSMVCOOPRESTfulSoftwareSoftware DevelopmentSoftware Engineering',
#        'Front endFront end developerJavaScriptdeveloperComputer ScienceCSSfront-endHTMLInformation Technology (IT)',
#        'backendBackend developerComputer ScienceNode.jsnodeJavaScriptAPIsAWSEngineeringGitInformation Technology (IT)MongoDBProgrammingSoftware DevelopmentMySQL',
#        'backendComputer SciencedeveloperInformation Technology (IT)Software DevelopmentSoftwarecomputerDevelopmentEngineering',
#        'AgileComputer ScienceAPIInformation Technology (IT)PHPLaravelSoftware Development',
#        'EngineeringflutterDevelopmentSoftware EngineeringSoftwareSoftware DevelopmentInformation Technology (IT)Computer ScienceAndroidGitJSONUI',
#        'Computer EngineeringComputer ScienceInformation Technology (IT)PHPSoftwareSoftware Development',
#        'AgileAPIbackendComputer ScienceInformation Technology (IT)JavaKotlinPythonRESTSoftwareSoftware EngineeringSpring',
#        'AngularComputer ScienceCSSDesignCSS3GitHTML5JavaScriptSoftware DevelopmentSass',
#        '.NetComputer ScienceDevelopmentCSSEngineeringHTML5Information Technology (IT)JavaScript',
#        'Software TestingQAQuality Assurancetestersofteware testerquality',
#        'ASP.NetC#AzureAgileCommunication skillsComputer ScienceInformation Technology (IT)GitMicrosoftMicrosoft SQL ServerSQLSoftware',
#        'PHPJenkinsAmazonSoftware DevelopmentSymfonyInformation Technology (IT)Web ServicesFrameworksElastic searchComputer ScienceAWSDocker',
#        'Front-End DevelopmentBack-End DevelopmentSoftware DevelopmentSoftware EngineeringComputer ScienceCSSEngineeringInformation Technology (IT)JavaScriptSoftwareSQLAgileHTML5Web Development',
#        'PHPHTMLWordPressWordPress Development',
#        'Computer ScienceFrontendInformation Technology (IT)ReactVue.jsfront-endJavaScript',
#        'HTML5Node.jsSoftware DevelopmentAgilefullstackfront-endBack-End DevelopmentWebsite DevelopmentInformation Technology (IT)',
#        'flutterMobile Developmentsenior flutterMobile App DevelopmentDart ProgrammingInformation Technology (IT)Software Development',
#        'Software DevelopmentComputer EngineeringRTOSc DeveloperInformation Technology (IT)EngineeringEmbedded SystemsProgrammingiOSSoftwareDevelopmentDesignComputer Science',
#        'softwaretypescriptNodeCompuer ScienceMongoDBReactAWSSQLHTMLNextCSSBootstrapERPPythonNoSQLSoftware TestingComputer ScienceInformation Technology (IT)Software Development',
#        'SoftwareComputer ScienceInformation Technology (IT)AgileAngular.Net FrameworkFull Stack DevelopmentAPIDevelopmentEngineeringJavaScriptRESTSQLSoftware Development',
#        'APIfluttermobile applicationsMobileSoftware DevelopmentFirebaseAgileDevelopmentSoftware',
#        'AngularSoftware DevelopmentInformation Technology (IT)Computer SciencejavaScriptCSSTestingUnit TestingAngular 6+UnitGitComputer EngineeringHTML5CSS3Front-EndAngular 6',
#        'Front endVue.jsJavaScript',
#        'ReactComputer ScienceInformation Technology (IT)JavaScript',
#        'APIsDockerEngineeringInformation Technology (IT)JavaRESTfulSoftware DevelopmentSQLComputer Science',
#        'AgileAngularComputer ScienceDesignGitInformation Technology (IT)JavaScriptProgrammingSoftwareSoftware DevelopmentSoftware EngineeringTesting',
#        'AngularComputer ScienceCSSfront-endHTMLHTML5Information Technology (IT)JavaScriptReactjQuerySoftware DevelopmentCSS3',
#        'JavaScriptProgrammingInformation Technology (IT)HTMLGit',
#        'Computer ScienceProgrammingSoftware DevelopmentInformation technologyDevelopmentBusiness AnalysisAutomationmobile applicationRESTfulflutterDesignGitAPIsJSON',
#        'Information Technology (IT)React NativeAndroid', nan,
#        'Computer ScienceAndroidDevelopmentProgrammingInformation Technology (IT)Software Development',
#        'Computer ScienceSoftware EngineeringInformation Systems.NETSoftware DevelopmentWeb DevelopmentWCFC#Microsoft SQL ServerNHibernatejavaScriptXML',
#        '.NetAngularFull Stack DevelopmentSoftwareSoftware DevelopmentASP.Net',
#        'AngularComputer ScienceCSS3DesignDevelopmentfront-endGitHTML5Information Technology (IT)JavaScriptSoftware DevelopmentUX'],
#       dtype=object)

# %%
#devops engineer 
#business analyst
#security engineer
#bi developer
#java developer
#software project manager 
#ai developer
#software support engineer 
#data analyst
#data scientest

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3518 entries, 0 to 3517
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         3518 non-null   object
#  1   company_name      3518 non-null   object
#  2   Job Location      3518 non-null   object
#  3   Work_Status       927 non-null    object
#  4   Work_Mode         921 non-null    object
#  5   Experience        3518 non-null   object
#  6   career_level      924 non-null    object
#  7   Education         3515 non-null   object
#  8   skills            924 non-null    object
#  9   job_description   3518 non-null   object
#  10  job_requirements  914 non-null    object
#  11  job_title_basic   3518 non-null   object
#  12  job_groups        3048 non-null   object
#  13  Technical Skills  3518 non-null   object
#  14  General Skills    3518 non-null   object
# dtypes: object(15)
# memory usage: 412.4+ KB

# %% [markdown]
# ### HANDLE THE SKILLS COLUMN

# %% [markdown]
# #### take advantage from the skill information come from wuzzaf website

# %%
unique_skills = {
    "General Skills": [
        "Agile", "Active Listening", "Analysis", "Architecture", "Automated Testing",
        "Brainstorming", "Calendar Management", "Change Management", "Client Retention Strategies",
        "Communication", "Communication Skills", "Conflict Mediation", "Conflict Resolution",
        "Consensus Building", "Cost Control", "Creative", "Creative Problem Solving",
        "Critical Thinking", "Cross-Cultural Communication", "Customer Care", "Customer Onboarding",
        "Customer Satisfaction Analysis", "Customer Service", "Data Interpretation", 
        "Deadlines Management", "Decision Making", "Decision Trees", "Delegation", "Design Sprint Facilitation",
        "Design Thinking", "Digital Marketing", "Documentation", "Empathy", "Empathy Development",
        "ERP Software", "Facilitation", "Feedback Delivery", "File Organization", 
        "Focus Strategies", "Goal Setting", "Growth", "Idea Generation", "Innovation",
        "Interpersonal Skills", "Leadership", "Leadership Styles", "Learning Management Systems (LMS)",
        "Management", "Market Research", "Mentorship", "Mind Mapping Tools",
        "Motivational Leadership", "Negotiation", "Negotiation Skills", "Networking Skills",
        "Nonverbal Communication", "Office Management", "Organization", "Planning", 
        "Presentation Design", "Presentation Skills", "Prioritization", "Problem Framing", 
        "Problem Solving", "Process Optimization", "Project Scheduling", "Proposal Writing", 
        "Prototyping", "Public Speaking", "Quality Assurance", "Quality Control", 
        "Relationship Marketing", "Relationship Management", "Research", "Respectfulness", 
        "Root Cause Analysis", "Root Cause Identification", "Sales Skills", 
        "Scenario Analysis", "Self-Awareness", "Self-Regulation", "Skill Gap Analysis", 
        "Solution Prototyping", "Stakeholder Management", "Strategic Thinking", 
        "Storytelling", "SWOT Analysis", "Team Collaboration", "Team Leadership", 
        "Team Mentorship", "Testing", "Time Blocking", "Time Management", 
        "To-Do List Management", "Trend Forecasting", "Training", "Vision Setting", 
        "Work Ethics", "Workforce Planning", "Writing"
    ],
    "Technical Skills": [
        ".Net", "3D Modeling", "Access Control", "AC ", "AI ", "Algorithm Development",
        "Amazon AWS", "Amazon Web Services (AWS)", "Android Development", "Angular", 
        "Apache Spark", "API Development", "Application Security", "Arduino", 
        "ASP.Net", "ASP.NET Core", "Automation", "AWS", "Azure", "Bash Scripting", 
        "Big Data", "Blockchain", "Blockchain Development", "Business Intelligence", 
        "C#", "C++", "CCTV", "Cloud", "Cloud Infrastructure", "Cloud Platforms", 
        "Cloud Security", "Communication", "Computer Vision Tools", "Confluence", 
        "Containerization", "Content Management", "CRM", "CSS", "Customer Support", 
        "Cybersecurity", "DAX (Data Analysis Expressions)", "Data Analysis", 
        "Data Engineering", "Data Governance", "Data Interpretation", "Data Science", 
        "Data Validation", "Data Visualization", "Database Administration", 
        "Database Development", "Decision Trees", "Design Thinking", "DevOps", 
        "Digital Marketing", "Docker", "Django", "E-Learning Module Design", 
        "E-commerce", "Elasticsearch", "Embedded Systems", "English", 
        "Engineering", "ERP", "ERP Software", "ETL Processes", "FastAPI", 
        "Figma", "Flask", "Flutter", "Frontend Development", "Genesys", "Git", 
        "Go Programming", "Google Analytics", "Google Cloud Platform", "GraphQL", 
        "Hardware Troubleshooting", "Heroku", "HTML", "IAM (Identity Access Management)", 
        "InVision", "Integration", "IoT (Internet of Things)", "IoT Development", 
        "IT Infrastructure", "ITIL", "Jenkins", "JIRA", "Kanban", "Kubernetes", 
        "Laravel", "Leadership", "Linux Administration", "Load Testing", 
        "Low Code/No Code Development", "Magento", "Machine Learning", "Matplotlib", 
        "Microsoft Access", "Microsoft Azure", "Microsoft Office", "Microsoft Office Suite", 
        "Microsoft Project", "Microsoft SQL Server", "Microsoft Word", "MongoDB", 
        "MySQL", "Natural Language Processing (NLP)", "Nest.js", "Network Security", 
        "Network Troubleshooting", "Node.js", "NoSQL Databases", "NumPy", 
        "Odoo ERP", "OpenCV", "Oracle", "Penetration Testing", "PHP", "PostgreSQL", 
        "Power BI", "Programming", "Project Management", "Proposal Writing", 
        "Python", "R Programming", "React.js", "Redux", "Ruby on Rails", 
        "SaaS", "Salesforce Development", "SAP ERP", "Scikit-learn", "SCRUM Framework", 
        "Security", "SEO", "SharePoint", "Shell Scripting", "Spring Boot", 
        "SQL", "SQLite", "SWOT Analysis", "Tableau", "TensorFlow", "Terraform", 
        "Testing", "Time Management", "Training", "TypeScript", "Unity", 
        "Unreal Engine", "Version Control", "Virtual Collaboration Tools", 
        "Virtualization", "Visual Basic", "Web Development", "WooCommerce", 
        "WordPress", "XML", "Zoho", "Zoho CRM",'IIBA', 'CBAP', 'ScrumMaster (CSM)', 'COBIT','CompTIA A+', 'CCNA'
        ,'SOLID principles','Develop optimal database schema','Develop database schema'
        
    ]
}

def get_skills(row, sk_l):
    allskills=set()
    # Ensure all columns are strings; if not, use an empty string as fallback
    sk_s = str(row['skills']) if pd.notna(row['skills']) else ''
    req_s = str(row['job_description']) if pd.notna(row['job_description']) else ''
    desc_s = str(row['job_requirements']) if pd.notna(row['job_requirements']) else ''

    # Iterate over skills list
    for sk in sk_l:
        if sk.lower() in sk_s.lower():
            allskills.add(sk)
        if sk.lower() in req_s.lower():
           allskills.add(sk)
        if sk.lower() in desc_s.lower():
            allskills.add(sk)
    
    return ','.join(allskills)

# Apply the function row-wise for Technical Skills
all_df['Technical Skills'] = all_df.apply(
    lambda row: get_skills(row, unique_skills['Technical Skills']), axis=1                                          
)

# Apply the function row-wise for General Skills
all_df['General Skills'] = all_df.apply(                                                                                                                                                                                                                                                                                                                                                                         
    lambda row: get_skills(row, unique_skills['General Skills']), axis=1
)

# %% [markdown]
# #### now having 2 columns one for technical skills and the other for the general skills coming from the skills,jobdescrebtion and job requirment columns

# %%
all_df['Technical Skills']
# Out:
# 0       Engineering,ERP,Git,SEO,Communication,Digital ...
# 1                   Communication,Programming,Flutter,CSS
# 2                     SaaS,Engineering,XML,Python,C++,SQL
# 3       Communication,Automation,Customer Support,English
# 4       Training,Engineering,Network Security,.Net,Acc...
#                               ...
# 3513                            Communication,Engineering
# 3514            Testing,Integration,English,Training,ITIL
# 3515                          Project Management,Training
# 3516           Data Engineering,Data Analysis,Engineering
# 3517                      Training,Data Analysis,Power BI
# Name: Technical Skills, Length: 3518, dtype: object

# %%
all_df['job_description'][0]
# Out:
# 'Our FounderDAZU Pay is a new FinTech startup founded by a Stanford graduate who just moved back from Silicon Valley to build DAZU.\xa0 Our founder has built over 150 web and mobile applications including for startups in the region (Valu, Cairo360), global tech unicorns (Google) and regional players (Du, MBC, the Saudi Government), and more.About DAZU PayDAZU is focused on building a leading edge platform supporting consumer and business payments in the Middle East & Africa.\xa0Our goal is to be the number one FinTech player in our niche in the Middle East & Africa.\xa0 Obviously, there’s more to it than that, but we’re still in stealth mode so you’ll know once we’ve launched (or if you join the team!)We have four products. we are launching and we are hiring product managers to join us.About the RoleWe’re looking for a number of hard-working and talented product managers with extensive experience in payments systems and platforms, including open banking, P2P payments, or cross-border payments. \xa0You will be managing one of our products at DAZU, including managing the launch of the product and customer engagement.Each Product Manager will be responsible for everything related to his/her Product and will include:Defining the product strategy with the Managing Director, including growth, marketing, sales, operational strategiesDefining growth strategies and implementing the strategy to increase user base and growth in target marketsDefining\xa0digital marketing strategy and implementing the strategy to reach users and track conversions to the productManaging and evolving the business model to manage revenue and grow the product revenue based on agreed on targets with the MDProduct roadmap including identifying new ideas and features to improve the UX and offerings for users and clients and improve downloads, engagement, app usage, referrals, etc.Working with the technical team, to manage timelines and budget for product development and deliveryMonitoring and tracking success of marketing and user growth through reports, analytic and others.'

# %%
all_df['General Skills'].value_counts()
# Out:
# General Skills
#                                                                                                                                       327
# Management                                                                                                                             91
# Architecture                                                                                                                           56
# Testing                                                                                                                                50
# Communication                                                                                                                          49
#                                                                                                                                      ...
# Analysis,Strategic Thinking,Management,Organization,Documentation,Interpersonal Skills,Growth,Communication,Stakeholder Management      1
# Leadership,Communication Skills,Management,Organization,Interpersonal Skills,Communication,Planning                                     1
# Leadership,Communication Skills,Organization,Management,Communication,Planning                                                          1
# Communication,Architecture,Communication Skills,Strategic Thinking                                                                      1
# Analysis,Testing,Presentation Skills,Management,Documentation,Interpersonal Skills,Communication,Training                               1
# Name: count, Length: 1913, dtype: int64

# %% [markdown]
# ### HANDLE JOB DESCREPTION AND JOB REQUIRMENT COLUMNS

# %%
all_df['job_description'][3420]
# Out:
# 'Job DescriptionRoles & ResponsibilitiesWrite clean, maintainable, and efficient code using best practices and design patternsImplement SOLID principles and ensure code qualityDevelop optimal database schema and secure data access layersCollaborate in requirements gathering and sprint planning sessions'

# %%
all_df[all_df['job_title'] == 'hr specialist']
# Out:
#           job_title          company_name                        Job Location  \
# 67    hr specialist            Wakeb Data                  Mohandessin - Giza
# 107   hr specialist          Data Science              Hadayek October - Giza
# 175   hr specialist         Spark Systems                   New Cairo - Cairo
# 194   hr specialist            Osolutions                   Nasr City - Cairo
# 613   hr specialist                unkown                    Sheraton - Cairo
# 693   hr specialist               StoreUs                       Maadi - Cairo
# 1573  hr specialist                Dautom        Dubai - United Arab Emirates
# 1639  hr specialist     GFWS Technologies  Dubai - United Arab Emirates (UAE)
# 3185  hr specialist    Petra Mechatronics                       Cairo - Egypt
# 3419  hr specialist  Yat Learning Centers                       Cairo - Egypt
#
#      Work_Status Work_Mode   Experience  \
# 67     Full Time   On-site  2 - 4 years
# 107    Full Time    Hybrid  1 - 3 years
# 175    Full Time   On-site  1 - 3 years
# 194    Full Time   On-site  3 - 7 years
# 613    Full Time   On-site  2 - 4 years
# 693    Full Time   On-site  2 - 5 years
# 1573         NaN       NaN  5 - 7 years
# 1639         NaN       NaN  0 - 2 years
# 3185         NaN       NaN  2 - 4 years
# 3419         NaN       NaN  3 - 6 years
#
#                                  career_level  \
# 67                  Experienced (Non-Manager)
# 107   Entry Level (Junior Level / Fresh Grad)
# 175                 Experienced (Non-Manager)
# 194                 Experienced (Non-Manager)
# 613                 Experienced (Non-Manager)
# 693                 Experienced (Non-Manager)
# 1573                                      NaN
# 1639                                      NaN
# 3185                                      NaN
# 3419                                      NaN
#
#                                             Education  \
# 67                                      Not Specified
# 107                                     Not Specified
# 175                                     Not Specified
# 194                                     Not Specified
# 613                                     Not Specified
# 693                                     Not Specified
# 1573                   Bachelor of Science(Computers)
# 1639                                   Any Graduation
# 3185               Bachelor of Technology/Engineering
# 3419  Bachelor of Business Administration(Management)
#
#                                                  skills  \
# 67         Human ResourcesMicrosoft OfficeCommunication
# 107   Human Resources (HR)Applicant Tracking Systems...
# 175   Human ResourcesHuman Resources (HR)PersonnelIn...
# 194   Human ResourcesIT/Software DevelopmentMarketin...
# 613   Human Resources (HR)ITSoftwareTechnical Recrui...
# 693                             Tech recruiterEcommerce
# 1573                                                NaN
# 1639                                                NaN
# 3185                                                NaN
# 3419                                                NaN
#
#                                         job_description  \
# 67    Write and post technical job descriptionsSourc...
# 107   Overview:We are seeking a highly motivated and...
# 175   Source potential candidates from niche platfor...
# 194   We are looking for an energetic Senior HR Spec...
# 613   Maintain knowledge of all policies and respond...
# 693   We are looking for a highly motivated and expe...
# 1573  Job DescriptionRoles & ResponsibilitiesJob Des...
# 1639  Job DescriptionRoles & ResponsibilitiesDesigni...
# 3185  Job DescriptionRoles & Responsibilities Job Ty...
# 3419  Job DescriptionRoles & ResponsibilitiesCreate ...
#
#                                        job_requirements  \
# 67    Education: Bachelor's degree in human resource...
# 107   Qualifications:Bachelor's degree in Human Reso...
# 175   Proven work experience as a Software Technical...
# 194   Marketing & PR Agencies Experience is a mustEd...
# 613   2-6 years of work experience as Recruiter for ...
# 693   Qualifications:Educational Background: Bachelo...
# 1573                                                NaN
# 1639                                                NaN
# 3185                                                NaN
# 3419                                                NaN
#
#                                  job_title_basic  \
# 67                Technical Recruiter Specialist
# 107                Talent Acquisition Specialist
# 175             HR Talent Acquisition Specialist
# 194                         Senior HR Specialist
# 613   Mid-level Technical Recruitment Specialist
# 693                                    Recruiter
# 1573                                IT Recruiter
# 1639                                HR Recruiter
# 3185                      IT Technical Recruiter
# 3419         IT Technical Recruitment Specialist
#
#                            job_groups  \
# 67    Miscellaneous and Support Roles
# 107   Miscellaneous and Support Roles
# 175   Miscellaneous and Support Roles
# 194   Miscellaneous and Support Roles
# 613   Miscellaneous and Support Roles
# 693   Miscellaneous and Support Roles
# 1573  Miscellaneous and Support Roles
# 1639  Miscellaneous and Support Roles
# 3185  Miscellaneous and Support Roles
# 3419  Miscellaneous and Support Roles
#
#                                        Technical Skills  \
# 67    Programming,ERP,Git,Time Management,Communicat...
# 107                                   Communication,ERP
# 175              Communication,Microsoft Office,English
# 194                                    Training,English
# 613     Communication,Microsoft Office,Training,English
# 693   Communication,WooCommerce,Engineering,E-commer...
# 1573  Engineering,Data Science,AWS,ERP,Communication...
# 1639                                       Training,ERP
# 3185                    Communication,Testing,WordPress
# 3419                                           Training
#
#                                          General Skills
# 67    Organization,Management,Interpersonal Skills,T...
# 107   Communication,Growth,Interpersonal Skills,Orga...
# 175       Communication,Communication Skills,Management
# 194                    Training,Organization,Management
# 613   Analysis,Negotiation Skills,Communication Skil...
# 693   Negotiation Skills,Organization,Digital Market...
# 1573  Communication,Communication Skills,Interperson...
# 1639                 Training,Documentation,Negotiation
# 3185  Analysis,Testing,Management,Organization,Docum...
# 3419                                           Training

# %%
all_df[-100:]
# Out:
#                      job_title                          company_name  \
# 3418  coordinator related jobs  Hampton Heights International School
# 3419             hr specialist                  Yat Learning Centers
# 3420      full stack developer                             A1Softech
# 3421          business analyst                        Total Energies
# 3422            data analytics           Al Ahly Momkn for e-paym...
# ...                        ...                                   ...
# 3513          business analyst                     Client of Xperts4
# 3514          business analyst                 Client of MigrationIT
# 3515   consultant related jobs                             Remotized
# 3516            data analytics                         Al Soug-Cashi
# 3517                instructor                             EpsilonAI
#
#                       Job Location Work_Status Work_Mode    Experience  \
# 3418  Dubai - United Arab Emirates         NaN       NaN  3 - 10 years
# 3419                 Cairo - Egypt         NaN       NaN   3 - 6 years
# 3420                  Giza - Egypt         NaN       NaN   3 - 5 years
# 3421  Dubai - United Arab Emirates         NaN       NaN   0 - 3 years
# 3422                 Cairo - Egypt         NaN       NaN   1 - 4 years
# ...                            ...         ...       ...           ...
# 3513   Saudi Arabia - Saudi Arabia         NaN       NaN   3 - 5 years
# 3514                 Egypt - Egypt         NaN       NaN   2 - 4 years
# 3515            Alexandria - Egypt         NaN       NaN   5 - 7 years
# 3516                  Giza - Egypt         NaN       NaN   2 - 5 years
# 3517                 Cairo - Egypt         NaN       NaN   2 - 4 years
#
#      career_level                                          Education skills  \
# 3418          NaN                                   Any Graduation()    NaN
# 3419          NaN    Bachelor of Business Administration(Management)    NaN
# 3420          NaN                     Bachelor of Science(Computers)    NaN
# 3421          NaN  Bachelor of Technology/Engineering, Bachelor o...    NaN
# 3422          NaN  Bachelor of Technology/Engineering, Bachelor o...    NaN
# ...           ...                                                ...    ...
# 3513          NaN                     Bachelor of Science(Computers)    NaN
# 3514          NaN                     Bachelor of Science(Computers)    NaN
# 3515          NaN                                   Any Graduation()    NaN
# 3516          NaN                                   Any Graduation()    NaN
# 3517          NaN                     Bachelor of Science(Computers)    NaN
#
#                                         job_description job_requirements  \
# 3418  Job DescriptionRoles & ResponsibilitiesJob Loc...              NaN
# 3419  Job DescriptionRoles & ResponsibilitiesCreate ...              NaN
# 3420  Job DescriptionRoles & ResponsibilitiesWrite c...              NaN
# 3421  Job DescriptionRoles & ResponsibilitiesJob Des...              NaN
# 3422  Job DescriptionRoles & ResponsibilitiesJob Des...              NaN
# ...                                                 ...              ...
# 3513  Job DescriptionRoles & ResponsibilitiesJob Des...              NaN
# 3514  Job DescriptionRoles & ResponsibilitiesBuild a...              NaN
# 3515  Job DescriptionRoles & ResponsibilitiesWe are ...              NaN
# 3516  Job DescriptionRoles & Responsibilities  Colle...              NaN
# 3517  Job DescriptionRoles & Responsibilities• As a ...              NaN
#
#                                         job_title_basic  \
# 3418                               Activity Coordinator
# 3419                IT Technical Recruitment Specialist
# 3420                        Senior Full Stack Developer
# 3421  Junior Business Analyst (UAE Nationals are enc...
# 3422                                       BI Developer
# ...                                                 ...
# 3513                                   Business Analyst
# 3514                            Sr. IT Business Analyst
# 3515                                     SOP Consultant
# 3516                                       Data Analyst
# 3517                Data Analysis, Analytics Instructor
#
#                              job_groups  \
# 3418  Project Management and Leadership
# 3419    Miscellaneous and Support Roles
# 3420               Software Development
# 3421    Miscellaneous and Support Roles
# 3422                 Data and Analytics
# ...                                 ...
# 3513    Miscellaneous and Support Roles
# 3514    Miscellaneous and Support Roles
# 3515    Miscellaneous and Support Roles
# 3516                 Data and Analytics
# 3517    Miscellaneous and Support Roles
#
#                                 Technical Skills  \
# 3418                                       Unity
# 3419                                    Training
# 3420
# 3421                                Training,Git
# 3422           SQL,ETL Processes,Power BI,Oracle
# ...                                          ...
# 3513                   Communication,Engineering
# 3514   Testing,Integration,English,Training,ITIL
# 3515                 Project Management,Training
# 3516  Data Engineering,Data Analysis,Engineering
# 3517             Training,Data Analysis,Power BI
#
#                                          General Skills
# 3418
# 3419                                           Training
# 3420                                           Planning
# 3421     Analysis,Management,Innovation,Growth,Training
# 3422
# ...                                                 ...
# 3513  Analysis,Communication,Communication Skills,Gr...
# 3514  Testing,Management,Documentation,Training,Plan...
# 3515                   Training,Organization,Management
# 3516                                           Analysis
# 3517                                  Analysis,Training
#
# [100 rows x 15 columns]

# %%
key_phrases = {
    "Strong Phrases": [
        "Proven ability to", "Proven experience in", "Strong analytical skills", 
        "Strong knowledge of", "Extensive experience with", "In-depth knowledge of", 
        "Expertise in", "Advanced proficiency in", "Highly proficient in", 
        "Exceptional ability to"
    ],
    "Middle Phrases": [
        "Experience with", "Knowledge of", "Prior experience with", 
        "Proficiency in", "Familiarity with", "Particularly with", 
        "Demonstrated ability to", "Solid understanding of", "Competence in", 
        "Working knowledge of"
    ],
    "Weak Phrases": [
        "Is a plus", "Is advantageous", "A big plus", "English Proficiency", 
        "Providing support for", "Basic knowledge of", "General understanding of", 
        "Willingness to learn", "Some experience in", "Exposure to"
    ]
}
def try_to_handle(x,l):
    
    

all_df['try']= all_df['job_requirements'].apply(lambda x: x if fuck_u.lower() in str(x).lower()  else '' )
desception=['Collect', 'clean','per-process','Create','maintain','Perform','identify','Collaborate with','enabling','comprehensive understanding of','clean, maintainable, and efficient code','ensure code quality']

# %%
fuck='Bachelors degree in computer engineering or computer science.Proven experience as an Oracle EBS Database Administrator, with a strong understanding of Oracle database architecture and administration.In-depth knowledge of Oracle EBS database components and utilities.'
wow=fuck.find('In-depth knowledge of')
not_wow=fuck.find('.',wow)
print(fuck.find('In-depth knowledge of'))
print(fuck.find('.',wow))
fuck[wow:not_wow]
# Out:
# 199
# 265
# 'In-depth knowledge of Oracle EBS database components and utilities'

# %%
all_df[all_df['try'] != '']['job_requirements'][7]
# Out:
# 'Bachelor’s degree in computer engineering or computer science.Proven experience as an Oracle EBS Database Administrator, with a strong understanding of Oracle database architecture and administration.In-depth knowledge of Oracle EBS database components and utilities.Experience in database performance tuning, capacity planning, and troubleshooting.Familiarity with backup and recovery strategies, including RMAN and Data Guard.Strong problem-solving and communication skills.Familiarity with Oracle database design, coding, and documentation.Ability to visualize algorithmic structures.Minimum 5 years of experience as an Oracle Database AdministratorStrong knowledge of Oracle database architecture and internalsExperience with Oracle 12c, 19c or higher environmentsProficiency in SQL and PL/SQL programmingExperience in performance tuning, monitoring, and optimization of Oracle databasesAbility to troubleshoot and resolve database issues effectively'
